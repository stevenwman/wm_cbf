# %%
from latent_dubins_gap_ddpg import LatentDubinGap, get_args, state_to_image_pil_hq
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from colorama import Fore, Back, Style
import matplotlib.colors as mcolors

class DubinEnv():
    def __init__(self, start_state, goal_state):
        self.start_state = start_state
        self.curr_state = start_state
        self.goal_state = goal_state
        self.args = get_args()
        self.v = self.args.speed
        self.dt = self.args.dt

    def forward(self, action):
        # Apply the action to the current state
        state_obs, img_obs, state_gt, dones, acs = ([] for _ in range(5))
        pstate = self.curr_state.copy()
        pstate[0] += self.v * np.cos(self.curr_state[2]) * self.dt
        pstate[1] += self.v * np.sin(self.curr_state[2]) * self.dt
        pstate[2] += action * self.dt  # Update the heading angle
        img = state_to_image_pil_hq(pstate, self.args)

        state_obs.append(pstate[2]) # get to observe theta
        state_gt.append(pstate) # gt state
        dones.append(1)
        acs.append(action)
        img_obs.append(img)

        demo = {}
        demo['obs'] = {'image': img_obs, 'state': state_obs, 'priv_state': state_gt}
        demo['actions'] = acs
        demo['dones'] = dones
        return demo, pstate
    
    def goal_ref(self):
        # Calculate the direction towards the goal
        dx = self.goal_state[0] - self.curr_state[0]
        dy = self.goal_state[1] - self.curr_state[1]
        angle_to_goal = np.arctan2(dy, dx)
        ref_theta = angle_to_goal
        delta_theta = ref_theta - self.curr_state[2]
        # Normalize the angle to be within [-pi, pi] using modulo operation
        delta_theta = (delta_theta + np.pi) % (2 * np.pi) - np.pi
        ref_theta_dot = (delta_theta) / self.dt

        return ref_theta, np.clip(ref_theta_dot, -self.args.turnRate, self.args.turnRate)

to_np = lambda x: x.cpu().detach().numpy()
# Out:
# /home/clown2/Desktop/Work/Research/wm_cbf

# %% [markdown]
# ## CBF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.5
gamma = 0.5
simlen = 100
u_min = -dubin_env.args.turnRate
u_max = dubin_env.args.turnRate
u_samples = 100
u_delta = (u_max - u_min) / u_samples
u_range = np.arange(u_min, u_max + u_delta, u_delta)  # action range for Dubins car
u_range = torch.tensor(u_range, dtype=torch.float32, device=brt.args.device).unsqueeze(-1)  # Convert to tensor

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()
    curr_safe = 1 

    Qzs = brt.evaluate_Q(to_np(feat), u_range)

    # import pdb; pdb.set_trace()

    # print(f"Qzs: {Qzs}")
    cbf_cond = Qzs > gamma * Vz

    # cbf_cond = Qzs > max(gamma * max(Vz, 0), epsilon)
    # print(f"CBF Condition: {cbf_cond}")
    Qzs_valid_idx = np.where(cbf_cond)[0]
    # print(f"u_range: {u_range.squeeze(-1).detach().cpu().numpy()}")

    if Qzs_valid_idx.size == 0:
        print(Fore.RED + "No valid actions found, using goal action."+Style.RESET_ALL)
        action = goal_act
    else:
        # Find the action that maximizes the Q-value while satisfying the CBF condition
        Qzs_valid = Qzs[Qzs_valid_idx]
        # Find the action that minimizes the distance to the goal action
        affordable_actions = torch.abs(u_range.squeeze(-1).masked_fill(torch.tensor(~cbf_cond, device=u_range.device), torch.inf) - goal_act)
        # print(f"Affordable actions: {affordable_actions}")
        closest_action = torch.argmin(affordable_actions)
        print(f"Closest action index: {closest_action}, Value: {Qzs[closest_action]}, Goal Action: {goal_act}")
        action = u_range[closest_action][0].detach().cpu().numpy()

    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action

    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    safe_values.append(safe_value)

    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])
    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 2)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot: black edge for trajectory points, red for intervention
# plot: white to red gradient for delta action magnitude
delta_action = np.abs(np.diff(np.array(actions), prepend=actions[0]))
colors = ["white", "red"]
custom_cmap = mcolors.LinearSegmentedColormap.from_list("white_red", colors)
norm = mcolors.Normalize(vmin=0, vmax=u_max - u_min)

# plot the trajectory history and circle obstacle
fig, ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)

for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)

plt.scatter(pss[:,0], pss[:,1], c=delta_action, s=10, label='Trajectory', cmap=custom_cmap, norm=norm, edgecolor='black', linewidth=0.25)
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()

# plot safe value over time
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='CBF Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 25916421 trainable variables (excluding margin heads).
# Optimizer margin_nogp has 543233 trainable variables.
# Optimizer margin_gp has 543233 trainable variables.
# Closest action index: 100, Value: 0.6218985319137573, Goal Action: 1.25
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.6100000143051147
# Closest action index: 100, Value: 0.6218985319137573, Goal Action: 1.25
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.6399999856948853
# Closest action index: 100, Value: 0.6608947515487671, Goal Action: 1.25
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.6600000262260437
# Closest action index: 100, Value: 0.6983293294906616, Goal Action: 1.25
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.6899999976158142
# Closest action index: 100, Value: 0.724606990814209, Goal Action: 1.25
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.7200000286102295
# Closest action index: 100, Value: 0.7365251779556274, Goal Action: 1.25
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.7400000095367432
# Closest action index: 100, Value: 0.7362552881240845, Goal Action: 1.25
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.7200000286102295
# Closest action index: 100, Value: 0.7182561159133911, Goal Action: 1.25
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.6800000071525574
# Closest action index: 100, Value: 0.6799643039703369, Goal Action: 1.25
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.6399999856948853
# Closest action index: 100, Value: 0.6433595418930054, Goal Action: 1.25
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.5799999833106995
# Closest action index: 100, Value: 0.5847659111022949, Goal Action: 1.25
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.5600000023841858
# Closest action index: 100, Value: 0.5320742130279541, Goal Action: 1.25
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.5600000023841858
# Closest action index: 60, Value: 0.5020473003387451, Goal Action: 1.25
# Step 13: Pstate: [-1.07  0.66 -0.81], Goal: -0.32, Action: 0.25, Dist: 2.17, Safe Value: 0.5699999928474426
# Closest action index: 49, Value: 0.5032851696014404, Goal Action: 1.25
# Step 14: Pstate: [-1.03  0.63 -0.81], Goal: -0.31, Action: -0.019999999552965164, Dist: 2.13, Safe Value: 0.5799999833106995
# Closest action index: 44, Value: 0.5023975372314453, Goal Action: 1.25
# Step 15: Pstate: [-1.    0.59 -0.82], Goal: -0.3, Action: -0.15000000596046448, Dist: 2.08, Safe Value: 0.5899999737739563
# Closest action index: 46, Value: 0.502089262008667, Goal Action: 1.25
# Step 16: Pstate: [-0.97  0.55 -0.82], Goal: -0.29, Action: -0.10000000149011612, Dist: 2.04, Safe Value: 0.6000000238418579
# Closest action index: 57, Value: 0.5017211437225342, Goal Action: 1.25
# Step 17: Pstate: [-0.93  0.52 -0.81], Goal: -0.27, Action: 0.18000000715255737, Dist: 2.0, Safe Value: 0.6200000047683716
# Closest action index: 57, Value: 0.5017106533050537, Goal Action: 1.25
# Step 18: Pstate: [-0.9   0.48 -0.8 ], Goal: -0.26, Action: 0.18000000715255737, Dist: 1.96, Safe Value: 0.6299999952316284
# Closest action index: 100, Value: 0.5035864114761353, Goal Action: 1.25
# Step 19: Pstate: [-0.86  0.44 -0.74], Goal: -0.25, Action: 1.25, Dist: 1.91, Safe Value: 0.6200000047683716
# Closest action index: 62, Value: 0.5015000104904175, Goal Action: 1.25
# Step 20: Pstate: [-0.83  0.41 -0.73], Goal: -0.23, Action: 0.30000001192092896, Dist: 1.87, Safe Value: 0.5899999737739563
# Closest action index: 47, Value: 0.5019329786300659, Goal Action: 1.25
# Step 21: Pstate: [-0.79  0.38 -0.73], Goal: -0.22, Action: -0.07999999821186066, Dist: 1.83, Safe Value: 0.5699999928474426
# Closest action index: 38, Value: 0.5003114938735962, Goal Action: 1.25
# Step 22: Pstate: [-0.75  0.34 -0.75], Goal: -0.21, Action: -0.30000001192092896, Dist: 1.78, Safe Value: 0.5299999713897705
# Closest action index: 17, Value: 0.5003899335861206, Goal Action: 1.25
# Step 23: Pstate: [-0.71  0.31 -0.79], Goal: -0.19, Action: -0.8199999928474426, Dist: 1.74, Safe Value: 0.4399999976158142
# No valid actions found, using goal action.
# Step 24: Pstate: [-0.68  0.27 -0.72], Goal: -0.18, Action: 1.25, Dist: 1.7, Safe Value: 0.1899999976158142
# No valid actions found, using goal action.
# Step 25: Pstate: [-0.64  0.24 -0.66], Goal: -0.16, Action: 1.25, Dist: 1.66, Safe Value: 0.44999998807907104
# No valid actions found, using goal action.
# Step 26: Pstate: [-0.6   0.21 -0.6 ], Goal: -0.15, Action: 1.25, Dist: 1.62, Safe Value: 0.5199999809265137
# Closest action index: 100, Value: 0.5180413126945496, Goal Action: 1.25
# Step 27: Pstate: [-0.56  0.18 -0.54], Goal: -0.13, Action: 1.25, Dist: 1.57, Safe Value: 0.5699999928474426
# Closest action index: 100, Value: 0.5718675255775452, Goal Action: 1.25
# Step 28: Pstate: [-0.52  0.16 -0.47], Goal: -0.12, Action: 1.25, Dist: 1.53, Safe Value: 0.6000000238418579
# Closest action index: 100, Value: 0.5971789360046387, Goal Action: 1.25
# Step 29: Pstate: [-0.47  0.13 -0.41], Goal: -0.1, Action: 1.25, Dist: 1.48, Safe Value: 0.6200000047683716
# Closest action index: 100, Value: 0.6166095733642578, Goal Action: 1.25
# Step 30: Pstate: [-0.43  0.11 -0.35], Goal: -0.09, Action: 1.25, Dist: 1.43, Safe Value: 0.6299999952316284
# Closest action index: 100, Value: 0.6334209442138672, Goal Action: 1.25
# Step 31: Pstate: [-0.38  0.1  -0.29], Goal: -0.08, Action: 1.25, Dist: 1.38, Safe Value: 0.6299999952316284
# Closest action index: 100, Value: 0.6345169544219971, Goal Action: 1.25
# Step 32: Pstate: [-0.33  0.08 -0.22], Goal: -0.07, Action: 1.25, Dist: 1.33, Safe Value: 0.6200000047683716
# Closest action index: 100, Value: 0.6250191330909729, Goal Action: 1.25
# Step 33: Pstate: [-0.28  0.07 -0.16], Goal: -0.06, Action: 1.25, Dist: 1.29, Safe Value: 0.5799999833106995
# Closest action index: 100, Value: 0.5864763259887695, Goal Action: 1.25
# Step 34: Pstate: [-0.23  0.06 -0.1 ], Goal: -0.06, Action: 1.25, Dist: 1.24, Safe Value: 0.5600000023841858
# Closest action index: 89, Value: 0.5468809604644775, Goal Action: 0.9704861242826368
# Step 35: Pstate: [-0.18  0.06 -0.05], Goal: -0.05, Action: 0.9800000190734863, Dist: 1.19, Safe Value: 0.550000011920929
# Closest action index: 51, Value: 0.5296684503555298, Goal Action: 0.036389737089868035
# Step 36: Pstate: [-0.13  0.06 -0.05], Goal: -0.05, Action: 0.019999999552965164, Dist: 1.14, Safe Value: 0.5099999904632568
# Closest action index: 25, Value: 0.5003542900085449, Goal Action: 0.01299161777226665
# Step 37: Pstate: [-0.08  0.05 -0.08], Goal: -0.05, Action: -0.6200000047683716, Dist: 1.09, Safe Value: 0.46000000834465027
# No valid actions found, using goal action.
# Step 38: Pstate: [-0.03  0.05 -0.05], Goal: -0.05, Action: 0.64, Dist: 1.04, Safe Value: 0.4399999976158142
# No valid actions found, using goal action.
# Step 39: Pstate: [ 0.02  0.05 -0.05], Goal: -0.05, Action: 0.03, Dist: 0.99, Safe Value: 0.4399999976158142
# No valid actions found, using goal action.
# Step 40: Pstate: [ 0.07  0.04 -0.05], Goal: -0.05, Action: 0.0, Dist: 0.94, Safe Value: 0.4699999988079071
# Closest action index: 50, Value: 0.5015600919723511, Goal Action: 8.350600567474942e-05
# Step 41: Pstate: [ 0.12  0.04 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.89, Safe Value: 0.49000000953674316
# Closest action index: 50, Value: 0.5198360681533813, Goal Action: 8.821922533819304e-05
# Step 42: Pstate: [ 0.17  0.04 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.84, Safe Value: 0.5299999713897705
# Closest action index: 50, Value: 0.5549585819244385, Goal Action: 9.349631488575483e-05
# Step 43: Pstate: [ 0.22  0.04 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.79, Safe Value: 0.5799999833106995
# Closest action index: 50, Value: 0.615437388420105, Goal Action: 9.944490086510882e-05
# Step 44: Pstate: [ 0.26  0.03 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.74, Safe Value: 0.6100000143051147
# Closest action index: 50, Value: 0.640295147895813, Goal Action: 0.00010620186132292986
# Step 45: Pstate: [ 0.31  0.03 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.69, Safe Value: 0.6600000262260437
# Closest action index: 50, Value: 0.6657251119613647, Goal Action: 0.00011394398802266892
# Step 46: Pstate: [ 0.36  0.03 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.64, Safe Value: 0.6899999976158142
# Closest action index: 50, Value: 0.6875361204147339, Goal Action: 0.00012290367894962628
# Step 47: Pstate: [ 0.41  0.03 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.59, Safe Value: 0.7099999785423279
# Closest action index: 50, Value: 0.6954525709152222, Goal Action: 0.00013339266643264125
# Step 48: Pstate: [ 0.46  0.03 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.54, Safe Value: 0.7200000286102295
# Closest action index: 50, Value: 0.6969586610794067, Goal Action: 0.00014583902899545365
# Step 49: Pstate: [ 0.51  0.02 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.49, Safe Value: 0.7200000286102295
# Closest action index: 50, Value: 0.6976802349090576, Goal Action: 0.00016084705630525775
# Step 50: Pstate: [ 0.56  0.02 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.44, Safe Value: 0.7099999785423279
# Closest action index: 50, Value: 0.6840561628341675, Goal Action: 0.00017929831771290594
# Step 51: Pstate: [ 0.61  0.02 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.39, Safe Value: 0.6700000166893005
# Closest action index: 50, Value: 0.6270133256912231, Goal Action: 0.00020253130807112996
# Step 52: Pstate: [ 0.66  0.02 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.34, Safe Value: 0.6399999856948853
# Closest action index: 50, Value: 0.5592770576477051, Goal Action: 0.00023268155353584064
# Step 53: Pstate: [ 0.71  0.01 -0.05], Goal: -0.05, Action: -0.0, Dist: 0.29, Safe Value: 0.5899999737739563
# Closest action index: 62, Value: 0.5002761483192444, Goal Action: 0.00027337863388154915
# Step 54: Pstate: [ 0.76  0.01 -0.03], Goal: -0.05, Action: 0.30000001192092896, Dist: 0.24, Safe Value: 0.5600000023841858
# Closest action index: 84, Value: 0.5024477243423462, Goal Action: -0.2996686821827854
# Step 55: Pstate: [0.81 0.01 0.01], Goal: -0.05, Action: 0.8500000238418579, Dist: 0.19, Safe Value: 0.5299999713897705
# Closest action index: 95, Value: 0.5009669065475464, Goal Action: -1.2302752233235204
# Step 56: Pstate: [0.86 0.01 0.07], Goal: -0.05, Action: 1.1200000047683716, Dist: 0.14, Safe Value: 0.5299999713897705
# Closest action index: 96, Value: 0.5046297311782837, Goal Action: -1.25
# Step 57: Pstate: [0.91 0.01 0.12], Goal: -0.07, Action: 1.149999976158142, Dist: 0.09, Safe Value: 0.550000011920929
# Closest action index: 87, Value: 0.5006094574928284, Goal Action: -1.25
# Step 58: Pstate: [0.96 0.02 0.17], Goal: -0.15, Action: 0.9200000166893005, Dist: 0.04, Safe Value: 0.5899999737739563
# Reached the goal!

# %% [markdown]
# ## LRSF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.4
simlen = 1000

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()    
    curr_safe = 1 

    if safe_value < epsilon: 
        safe_action = brt.find_a(feat.detach().cpu().numpy())
        action = safe_action[0]
        curr_safe = 0 # when safe action is engaged
        print(Fore.RED + 'Safe action engaged!' + Style.RESET_ALL)
    else:
        action = goal_act # nominal action otherwise
    
    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    
    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action
    
    safe_values.append(safe_value)
    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])

    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 3)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot: black edge for trajectory points, red for intervention
# plot: white to red gradient for delta action magnitude
delta_action = np.abs(np.diff(np.array(actions), prepend=actions[0]))
colors = ["white", "red"]
custom_cmap = mcolors.LinearSegmentedColormap.from_list("white_red", colors)
norm = mcolors.Normalize(vmin=0, vmax=u_max - u_min)

# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)
safe_action_idx = np.where(np.array(current_safe) == 1)
unsafe_action_idx = np.where(np.array(current_safe) == 0)
plt.scatter(pss[safe_action_idx][:,0], pss[safe_action_idx][:,1], c=delta_action[safe_action_idx], s=10, label='Trajectory', cmap=custom_cmap, norm=norm, linewidths=0.25, edgecolor='black')
plt.scatter(pss[unsafe_action_idx][:,0], pss[unsafe_action_idx][:,1], c=delta_action[unsafe_action_idx], s=10, label='Trajectory', cmap=custom_cmap, norm=norm, linewidths=0.25, edgecolor='red')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()
    
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='Safety Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 25916421 trainable variables (excluding margin heads).
# Optimizer margin_nogp has 543233 trainable variables.
# Optimizer margin_gp has 543233 trainable variables.
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.6140000224113464
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.6359999775886536
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.6589999794960022
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.6899999976158142
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.7170000076293945
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.7360000014305115
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.7179999947547913
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.6800000071525574
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.6430000066757202
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.5830000042915344
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.5619999766349792
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.5609999895095825
# Step 13: Pstate: [-1.07  0.66 -0.76], Goal: -0.32, Action: 1.25, Dist: 2.17, Safe Value: 0.5709999799728394
# Step 14: Pstate: [-1.03  0.63 -0.7 ], Goal: -0.31, Action: 1.25, Dist: 2.13, Safe Value: 0.5860000252723694
# Step 15: Pstate: [-0.99  0.6  -0.63], Goal: -0.3, Action: 1.25, Dist: 2.08, Safe Value: 0.6110000014305115
# Step 16: Pstate: [-0.95  0.57 -0.57], Goal: -0.29, Action: 1.25, Dist: 2.03, Safe Value: 0.6209999918937683
# Step 17: Pstate: [-0.91  0.54 -0.51], Goal: -0.28, Action: 1.25, Dist: 1.99, Safe Value: 0.597000002861023
# Step 18: Pstate: [-0.87  0.51 -0.45], Goal: -0.27, Action: 1.25, Dist: 1.94, Safe Value: 0.5350000262260437
# Step 19: Pstate: [-0.82  0.49 -0.38], Goal: -0.27, Action: 1.25, Dist: 1.89, Safe Value: 0.4569999873638153
# Step 20: Pstate: [-0.78  0.47 -0.32], Goal: -0.26, Action: 1.25, Dist: 1.84, Safe Value: 0.3569999933242798
# Safe action engaged!
# Step 21: Pstate: [-0.73  0.46 -0.38], Goal: -0.26, Action: -1.25, Dist: 1.79, Safe Value: 0.26600000262260437
# Safe action engaged!
# Step 22: Pstate: [-0.68  0.44 -0.45], Goal: -0.26, Action: -1.25, Dist: 1.74, Safe Value: 0.2590000033378601
# Safe action engaged!
# Step 23: Pstate: [-0.64  0.42 -0.51], Goal: -0.26, Action: -1.25, Dist: 1.69, Safe Value: 0.24699999392032623
# Safe action engaged!
# Step 24: Pstate: [-0.59  0.39 -0.57], Goal: -0.25, Action: -1.25, Dist: 1.64, Safe Value: 0.27799999713897705
# Safe action engaged!
# Step 25: Pstate: [-0.55  0.37 -0.63], Goal: -0.24, Action: -1.25, Dist: 1.59, Safe Value: 0.3070000112056732
# Safe action engaged!
# Step 26: Pstate: [-0.51  0.34 -0.7 ], Goal: -0.23, Action: -1.25, Dist: 1.55, Safe Value: 0.2540000081062317
# Safe action engaged!
# Step 27: Pstate: [-0.47  0.3  -0.68], Goal: -0.22, Action: 0.33000001311302185, Dist: 1.5, Safe Value: 0.33399999141693115
# Safe action engaged!
# Step 28: Pstate: [-0.43  0.27 -0.62], Goal: -0.2, Action: 1.25, Dist: 1.46, Safe Value: 0.2770000100135803
# Safe action engaged!
# Step 29: Pstate: [-0.39  0.24 -0.55], Goal: -0.19, Action: 1.25, Dist: 1.41, Safe Value: 0.2630000114440918
# Safe action engaged!
# Step 30: Pstate: [-0.35  0.22 -0.5 ], Goal: -0.17, Action: 1.059999942779541, Dist: 1.37, Safe Value: 0.2070000022649765
# Safe action engaged!
# Step 31: Pstate: [-0.31  0.19 -0.56], Goal: -0.16, Action: -1.25, Dist: 1.32, Safe Value: 0.13500000536441803
# Safe action engaged!
# Step 32: Pstate: [-0.26  0.17 -0.63], Goal: -0.15, Action: -1.25, Dist: 1.28, Safe Value: 0.18199999630451202
# Safe action engaged!
# Step 33: Pstate: [-0.22  0.14 -0.69], Goal: -0.13, Action: -1.2400000095367432, Dist: 1.23, Safe Value: 0.24400000274181366
# Safe action engaged!
# Step 34: Pstate: [-0.19  0.11 -0.63], Goal: -0.11, Action: 1.2100000381469727, Dist: 1.19, Safe Value: 0.2840000092983246
# Safe action engaged!
# Step 35: Pstate: [-0.14  0.08 -0.57], Goal: -0.09, Action: 1.25, Dist: 1.15, Safe Value: 0.3089999854564667
# Safe action engaged!
# Step 36: Pstate: [-0.1   0.05 -0.5 ], Goal: -0.07, Action: 1.25, Dist: 1.1, Safe Value: 0.3490000069141388
# Safe action engaged!
# Step 37: Pstate: [-0.06  0.03 -0.44], Goal: -0.05, Action: 1.2400000095367432, Dist: 1.06, Safe Value: 0.38199999928474426
# Safe action engaged!
# Step 38: Pstate: [-0.01  0.   -0.38], Goal: -0.02, Action: 1.25, Dist: 1.01, Safe Value: 0.4020000100135803
# Step 39: Pstate: [ 0.03 -0.01 -0.32], Goal: -0.0, Action: 1.25, Dist: 0.97, Safe Value: 0.421999990940094
# Step 40: Pstate: [ 0.08 -0.03 -0.25], Goal: 0.01, Action: 1.25, Dist: 0.92, Safe Value: 0.4490000009536743
# Step 41: Pstate: [ 0.13 -0.04 -0.19], Goal: 0.03, Action: 1.25, Dist: 0.87, Safe Value: 0.48899999260902405
# Step 42: Pstate: [ 0.18 -0.05 -0.13], Goal: 0.05, Action: 1.25, Dist: 0.82, Safe Value: 0.4959999918937683
# Step 43: Pstate: [ 0.23 -0.06 -0.07], Goal: 0.06, Action: 1.25, Dist: 0.77, Safe Value: 0.5440000295639038
# Step 44: Pstate: [ 0.28 -0.06 -0.  ], Goal: 0.07, Action: 1.25, Dist: 0.73, Safe Value: 0.5759999752044678
# Step 45: Pstate: [ 0.33 -0.06  0.06], Goal: 0.08, Action: 1.25, Dist: 0.68, Safe Value: 0.6320000290870667
# Step 46: Pstate: [ 0.38 -0.06  0.09], Goal: 0.09, Action: 0.64, Dist: 0.63, Safe Value: 0.6690000295639038
# Step 47: Pstate: [ 0.43 -0.05  0.09], Goal: 0.09, Action: 0.05, Dist: 0.58, Safe Value: 0.7059999704360962
# Step 48: Pstate: [ 0.48 -0.05  0.09], Goal: 0.09, Action: 0.0, Dist: 0.53, Safe Value: 0.7279999852180481
# Step 49: Pstate: [ 0.53 -0.04  0.09], Goal: 0.09, Action: 0.0, Dist: 0.48, Safe Value: 0.7429999709129333
# Step 50: Pstate: [ 0.58 -0.04  0.09], Goal: 0.09, Action: 0.0, Dist: 0.43, Safe Value: 0.7429999709129333
# Step 51: Pstate: [ 0.63 -0.04  0.09], Goal: 0.09, Action: 0.0, Dist: 0.38, Safe Value: 0.7229999899864197
# Step 52: Pstate: [ 0.68 -0.03  0.09], Goal: 0.09, Action: 0.0, Dist: 0.33, Safe Value: 0.7059999704360962
# Step 53: Pstate: [ 0.73 -0.03  0.09], Goal: 0.09, Action: 0.0, Dist: 0.28, Safe Value: 0.6759999990463257
# Step 54: Pstate: [ 0.78 -0.02  0.09], Goal: 0.09, Action: 0.0, Dist: 0.23, Safe Value: 0.6380000114440918
# Step 55: Pstate: [ 0.83 -0.02  0.09], Goal: 0.09, Action: 0.0, Dist: 0.18, Safe Value: 0.6000000238418579
# Step 56: Pstate: [ 0.88 -0.01  0.09], Goal: 0.09, Action: 0.0, Dist: 0.13, Safe Value: 0.5830000042915344
# Step 57: Pstate: [ 0.92 -0.01  0.09], Goal: 0.09, Action: 0.0, Dist: 0.08, Safe Value: 0.5640000104904175
# Step 58: Pstate: [ 0.97 -0.    0.09], Goal: 0.09, Action: 0.0, Dist: 0.03, Safe Value: 0.5640000104904175
# Reached the goal!
