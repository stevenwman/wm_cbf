# %%
from latent_dubins_gap import LatentDubinGap, get_args, state_to_image_pil_hq
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from colorama import Fore, Back, Style

class DubinEnv():
    def __init__(self, start_state, goal_state):
        self.start_state = start_state
        self.curr_state = start_state
        self.goal_state = goal_state
        self.args = get_args()
        self.v = self.args.speed
        self.dt = self.args.dt

    def forward(self, action):
        # Apply the action to the current state
        state_obs, img_obs, state_gt, dones, acs = ([] for _ in range(5))
        pstate = self.curr_state.copy()
        pstate[0] += self.v * np.cos(self.curr_state[2]) * self.dt
        pstate[1] += self.v * np.sin(self.curr_state[2]) * self.dt
        pstate[2] += action * self.dt  # Update the heading angle
        img = state_to_image_pil_hq(pstate, self.args)

        state_obs.append(pstate[2]) # get to observe theta
        state_gt.append(pstate) # gt state
        dones.append(1)
        acs.append(action)
        img_obs.append(img)

        demo = {}
        demo['obs'] = {'image': img_obs, 'state': state_obs, 'priv_state': state_gt}
        demo['actions'] = acs
        demo['dones'] = dones
        return demo, pstate
    
    def goal_ref(self):
        # Calculate the direction towards the goal
        dx = self.goal_state[0] - self.curr_state[0]
        dy = self.goal_state[1] - self.curr_state[1]
        angle_to_goal = np.arctan2(dy, dx)
        ref_theta = angle_to_goal
        delta_theta = ref_theta - self.curr_state[2]
        # Normalize the angle to be within [-pi, pi] using modulo operation
        delta_theta = (delta_theta + np.pi) % (2 * np.pi) - np.pi
        ref_theta_dot = (delta_theta) / self.dt

        return ref_theta, np.clip(ref_theta_dot, -self.args.turnRate, self.args.turnRate)

to_np = lambda x: x.cpu().detach().numpy()
# Out:
# /home/clown2/Desktop/Work/Research/wm_cbf

# %% [markdown]
# ## CBF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.2
gamma = 0.9
simlen = 100
u_min = -dubin_env.args.turnRate
u_max = dubin_env.args.turnRate
u_samples = 100
u_delta = (u_max - u_min) / u_samples
u_range = np.arange(u_min, u_max + u_delta, u_delta)  # action range for Dubins car
u_range = torch.tensor(u_range, dtype=torch.float32, device=brt.args.device).unsqueeze(-1)  # Convert to tensor

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
Vz = np.min([Vz, to_np(Lz)])



for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()
    curr_safe = 1 

    Qzs = brt.evaluate_Q(to_np(feat), u_range)
    # print(f"Qzs: {Qzs}")
    cbf_cond = Qzs > gamma * Vz
    # print(f"CBF Condition: {cbf_cond}")
    Qzs_valid_idx = np.where(cbf_cond)[0]
    # print(f"u_range: {u_range.squeeze(-1).detach().cpu().numpy()}")

    if Qzs_valid_idx.size == 0:
        print(Fore.RED + "No valid actions found, using goal action."+Style.RESET_ALL)
        action = goal_act
    else:
        # Find the action that maximizes the Q-value while satisfying the CBF condition
        Qzs_valid = Qzs[Qzs_valid_idx]
        # Find the action that minimizes the distance to the goal action
        affordable_actions = torch.abs(u_range.squeeze(-1).masked_fill(torch.tensor(~cbf_cond, device=u_range.device), torch.inf) - goal_act)
        # print(f"Affordable actions: {affordable_actions}")
        closest_action = torch.argmin(affordable_actions)
        print(f"Closest action index: {closest_action}, Value: {Qzs[closest_action]}, Goal Action: {goal_act}")
        action = u_range[closest_action][0].detach().cpu().numpy()

    demo, priv_state = dubin_env.forward(action)
    feat = brt.data_to_feat(demo)
    Vz = brt.evaluate_V(to_np(feat))[0]
    Lz = brt.margin_fn(feat)[0][0][0]
    Vz = np.min([Vz, to_np(Lz)])
    safe_value = Vz = np.min([Vz, to_np(Lz)])
    dubin_env.curr_state = priv_state  # Update the current state in the environment

    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    safe_values.append(safe_value)

    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])
    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 2)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break


# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
# circle = patches.Circle((0,0), 0.5, edgecolor=(1,0,0), facecolor='none')
# ax.add_patch(circle)

for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)

col = np.where(np.array(current_safe) == 1, 'blue', 'red')
plt.scatter(pss[:,0], pss[:,1], c=col, s=10, label='Trajectory')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()

# plot safe value over time
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='CBF Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# /home/clown2/anaconda3/envs/wm_cbf/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# /home/clown2/Desktop/Work/Research/wm_cbf/PytorchReachability/dreamerv3-torch/tools.py:889: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self._scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# Optimizer model_opt has 27002886 variables.
# Closest action index: 50, Value: -0.17136898636817932, Goal Action: 0.0
# Step 1: Pstate: [-1.25  0.   -0.  ], Goal: 0.0, Action: -0.0, Dist: 2.45, Safe Value: -0.20000000298023224
# Closest action index: 50, Value: -0.17136898636817932, Goal Action: 0.0
# Step 2: Pstate: [-1.2 -0.  -0. ], Goal: 0.0, Action: -0.0, Dist: 2.4, Safe Value: -0.14000000059604645
# Closest action index: 86, Value: -0.1253005862236023, Goal Action: 8.881784197001252e-15
# Step 3: Pstate: [-1.15 -0.    0.04], Goal: 0.0, Action: 0.8999999761581421, Dist: 2.35, Safe Value: -0.009999999776482582
# Closest action index: 92, Value: -0.009482532739639282, Goal Action: -0.8999999761581368
# Step 4: Pstate: [-1.1  0.   0.1], Goal: 0.0, Action: 1.0499999523162842, Dist: 2.3, Safe Value: 0.14000000059604645
# Closest action index: 0, Value: 0.14350625872612, Goal Action: -1.25
# Step 5: Pstate: [-1.05  0.01  0.03], Goal: -0.0, Action: -1.25, Dist: 2.25, Safe Value: 0.1599999964237213
# Closest action index: 16, Value: 0.14617770910263062, Goal Action: -0.7632495775385806
# Step 6: Pstate: [-1.    0.01 -0.01], Goal: -0.0, Action: -0.8500000238418579, Dist: 2.2, Safe Value: 0.15000000596046448
# Closest action index: 12, Value: 0.13525834679603577, Goal Action: 0.06941072577253848
# Step 7: Pstate: [-0.95  0.01 -0.06], Goal: -0.0, Action: -0.949999988079071, Dist: 2.15, Safe Value: 0.10000000149011612
# Closest action index: 1, Value: 0.0969463586807251, Goal Action: 1.0210246606531204
# Step 8: Pstate: [-0.9   0.01 -0.12], Goal: -0.0, Action: -1.2200000286102295, Dist: 2.1, Safe Value: 0.07000000029802322
# Closest action index: 0, Value: 0.0717611014842987, Goal Action: 1.25
# Step 9: Pstate: [-0.85 -0.   -0.18], Goal: -0.0, Action: -1.25, Dist: 2.05, Safe Value: -0.009999999776482582
# Closest action index: 100, Value: 0.05588611960411072, Goal Action: 1.25
# Step 10: Pstate: [-0.8  -0.01 -0.12], Goal: 0.0, Action: 1.25, Dist: 2.0, Safe Value: 0.05000000074505806
# Closest action index: 100, Value: 0.17026829719543457, Goal Action: 1.25
# Step 11: Pstate: [-0.75 -0.01 -0.05], Goal: 0.0, Action: 1.25, Dist: 1.95, Safe Value: 0.12999999523162842
# Closest action index: 99, Value: 0.28270694613456726, Goal Action: 1.226096275884041
# Step 12: Pstate: [-0.7  -0.02  0.01], Goal: 0.01, Action: 1.2200000286102295, Dist: 1.9, Safe Value: 0.2199999988079071
# Closest action index: 51, Value: 0.22865736484527588, Goal Action: 0.03330751479138527
# Step 13: Pstate: [-0.65 -0.02  0.01], Goal: 0.01, Action: 0.019999999552965164, Dist: 1.85, Safe Value: 0.2800000011920929
# Closest action index: 57, Value: 0.2551574110984802, Goal Action: 0.009206735499205365
# Step 14: Pstate: [-0.6  -0.02  0.02], Goal: 0.01, Action: 0.18000000715255737, Dist: 1.8, Safe Value: 0.3499999940395355
# Closest action index: 57, Value: 0.3162522315979004, Goal Action: -0.16553780548424157
# Step 15: Pstate: [-0.55 -0.02  0.03], Goal: 0.01, Action: 0.18000000715255737, Dist: 1.75, Safe Value: 0.4099999964237213
# Closest action index: 36, Value: 0.37662243843078613, Goal Action: -0.3452619437181159
# Step 16: Pstate: [-0.5  -0.01  0.01], Goal: 0.01, Action: -0.3499999940395355, Dist: 1.7, Safe Value: 0.4099999964237213
# Closest action index: 50, Value: 0.4116482734680176, Goal Action: -0.005404104251214292
# Step 17: Pstate: [-0.45 -0.01  0.01], Goal: 0.01, Action: -0.0, Dist: 1.65, Safe Value: 0.47999998927116394
# Closest action index: 71, Value: 0.4304174780845642, Goal Action: -0.005567663862082739
# Step 18: Pstate: [-0.4  -0.01  0.03], Goal: 0.01, Action: 0.5199999809265137, Dist: 1.6, Safe Value: 0.47999998927116394
# Closest action index: 74, Value: 0.42842352390289307, Goal Action: -0.5307414091598517
# Step 19: Pstate: [-0.35 -0.01  0.06], Goal: 0.01, Action: 0.6000000238418579, Dist: 1.55, Safe Value: 0.44999998807907104
# Closest action index: 63, Value: 0.4091504216194153, Goal Action: -1.1478375372811023
# Step 20: Pstate: [-0.3  -0.01  0.08], Goal: 0.01, Action: 0.3199999928474426, Dist: 1.5, Safe Value: 0.3199999928474426
# Closest action index: 0, Value: 0.31495699286460876, Goal Action: -1.25
# Step 21: Pstate: [-0.25 -0.    0.02], Goal: 0.01, Action: -1.25, Dist: 1.45, Safe Value: 0.3499999940395355
# Closest action index: 82, Value: 0.3143339455127716, Goal Action: -0.31299657094059796
# Step 22: Pstate: [-0.2  -0.    0.06], Goal: 0.0, Action: 0.800000011920929, Dist: 1.4, Safe Value: 0.25
# Closest action index: 5, Value: 0.2567860782146454, Goal Action: -1.124156353458119
# Step 23: Pstate: [-0.15 -0.    0.  ], Goal: 0.0, Action: -1.1200000047683716, Dist: 1.35, Safe Value: 0.23999999463558197
# Closest action index: 48, Value: 0.24773648381233215, Goal Action: -0.04069702106892059
# Step 24: Pstate: [-0.1 -0.  -0. ], Goal: 0.0, Action: -0.05000000074505806, Dist: 1.3, Safe Value: 0.23000000417232513
# Closest action index: 50, Value: 0.2591506242752075, Goal Action: 0.0077405567625987715
# Step 25: Pstate: [-0.05 -0.   -0.  ], Goal: 0.0, Action: -0.0, Dist: 1.25, Safe Value: 0.23999999463558197
# Closest action index: 50, Value: 0.26951003074645996, Goal Action: 0.008049593577776903
# Step 26: Pstate: [-0. -0. -0.], Goal: 0.0, Action: -0.0, Dist: 1.2, Safe Value: 0.23000000417232513
# Closest action index: 50, Value: 0.25513333082199097, Goal Action: 0.008384332738691214
# Step 27: Pstate: [ 0.05 -0.   -0.  ], Goal: 0.0, Action: -0.0, Dist: 1.15, Safe Value: 0.20000000298023224
# Closest action index: 50, Value: 0.2284756302833557, Goal Action: 0.00874811983561763
# Step 28: Pstate: [ 0.1 -0.  -0. ], Goal: 0.0, Action: -0.0, Dist: 1.1, Safe Value: 0.12999999523162842
# Closest action index: 50, Value: 0.21427929401397705, Goal Action: 0.009144907441127614
# Step 29: Pstate: [ 0.15 -0.   -0.  ], Goal: 0.0, Action: -0.0, Dist: 1.05, Safe Value: 0.25999999046325684
# Closest action index: 76, Value: 0.23294229805469513, Goal Action: 0.009579399304477931
# Step 30: Pstate: [ 0.2  -0.    0.03], Goal: 0.0, Action: 0.6499999761581421, Dist: 1.0, Safe Value: 0.23999999463558197
# Closest action index: 82, Value: 0.21500085294246674, Goal Action: -0.6399427384561029
# Step 31: Pstate: [0.25 0.   0.07], Goal: 0.0, Action: 0.800000011920929, Dist: 0.95, Safe Value: 0.23000000417232513
# Closest action index: 88, Value: 0.20808137953281403, Goal Action: -1.25
# Step 32: Pstate: [0.3  0.   0.12], Goal: -0.0, Action: 0.949999988079071, Dist: 0.9, Safe Value: 0.2199999988079071
# Closest action index: 88, Value: 0.19765695929527283, Goal Action: -1.25
# Step 33: Pstate: [0.35 0.01 0.17], Goal: -0.01, Action: 0.949999988079071, Dist: 0.85, Safe Value: 0.2199999988079071
# Closest action index: 83, Value: 0.20088058710098267, Goal Action: -1.25
# Step 34: Pstate: [0.4  0.02 0.21], Goal: -0.01, Action: 0.8199999928474426, Dist: 0.8, Safe Value: 0.2199999988079071
# Closest action index: 83, Value: 0.19885802268981934, Goal Action: -1.25
# Step 35: Pstate: [0.45 0.03 0.25], Goal: -0.02, Action: 0.8199999928474426, Dist: 0.76, Safe Value: 0.20000000298023224
# Closest action index: 76, Value: 0.17739097774028778, Goal Action: -1.25
# Step 36: Pstate: [0.49 0.04 0.28], Goal: -0.04, Action: 0.6499999761581421, Dist: 0.71, Safe Value: 0.1899999976158142
# Closest action index: 87, Value: 0.17310908436775208, Goal Action: -1.25
# Step 37: Pstate: [0.54 0.06 0.33], Goal: -0.06, Action: 0.9200000166893005, Dist: 0.66, Safe Value: 0.20999999344348907
# Closest action index: 76, Value: 0.18846186995506287, Goal Action: -1.25
# Step 38: Pstate: [0.59 0.07 0.36], Goal: -0.08, Action: 0.6499999761581421, Dist: 0.62, Safe Value: 0.2199999988079071
# Closest action index: 87, Value: 0.19391672313213348, Goal Action: -1.25
# Step 39: Pstate: [0.64 0.09 0.41], Goal: -0.12, Action: 0.9200000166893005, Dist: 0.57, Safe Value: 0.20999999344348907
# Closest action index: 87, Value: 0.18672652542591095, Goal Action: -1.25
# Step 40: Pstate: [0.68 0.11 0.45], Goal: -0.16, Action: 0.9200000166893005, Dist: 0.53, Safe Value: 0.25
# Closest action index: 87, Value: 0.2239512801170349, Goal Action: -1.25
# Step 41: Pstate: [0.73 0.13 0.5 ], Goal: -0.21, Action: 0.9200000166893005, Dist: 0.49, Safe Value: 0.27000001072883606
# Closest action index: 90, Value: 0.24371284246444702, Goal Action: -1.25
# Step 42: Pstate: [0.77 0.16 0.55], Goal: -0.27, Action: 1.0, Dist: 0.46, Safe Value: 0.1899999976158142
# Closest action index: 43, Value: 0.17317837476730347, Goal Action: -1.25
# Step 43: Pstate: [0.81 0.18 0.54], Goal: -0.35, Action: -0.18000000715255737, Dist: 0.43, Safe Value: 0.1899999976158142
# Closest action index: 30, Value: 0.174479141831398, Goal Action: -1.25
# Step 44: Pstate: [0.86 0.21 0.52], Goal: -0.44, Action: -0.5, Dist: 0.4, Safe Value: 0.25
# Closest action index: 47, Value: 0.2237056940793991, Goal Action: -1.25
# Step 45: Pstate: [0.9  0.23 0.51], Goal: -0.54, Action: -0.07999999821186066, Dist: 0.38, Safe Value: 0.27000001072883606
# Closest action index: 54, Value: 0.24071523547172546, Goal Action: -1.25
# Step 46: Pstate: [0.94 0.26 0.52], Goal: -0.66, Action: 0.10000000149011612, Dist: 0.36, Safe Value: 0.2800000011920929
# Closest action index: 13, Value: 0.2506566643714905, Goal Action: -1.25
# Step 47: Pstate: [0.99 0.28 0.47], Goal: -0.78, Action: -0.9200000166893005, Dist: 0.35, Safe Value: 0.25
# Closest action index: 0, Value: 0.30912888050079346, Goal Action: -1.25
# Step 48: Pstate: [1.03 0.3  0.41], Goal: -0.92, Action: -1.25, Dist: 0.35, Safe Value: 0.20000000298023224
# Closest action index: 0, Value: 0.36340421438217163, Goal Action: -1.25
# Step 49: Pstate: [1.08 0.32 0.35], Goal: -1.06, Action: -1.25, Dist: 0.35, Safe Value: 0.12999999523162842
# Closest action index: 0, Value: 0.36470943689346313, Goal Action: -1.25
# Step 50: Pstate: [1.12 0.34 0.28], Goal: -1.21, Action: -1.25, Dist: 0.35, Safe Value: 0.07999999821186066
# Closest action index: 0, Value: 0.36013394594192505, Goal Action: -1.25
# Step 51: Pstate: [1.17 0.35 0.22], Goal: -1.35, Action: -1.25, Dist: 0.36, Safe Value: 0.03999999910593033
# Closest action index: 0, Value: 0.36429131031036377, Goal Action: -1.25
# Step 52: Pstate: [1.22 0.37 0.16], Goal: -1.49, Action: -1.25, Dist: 0.37, Safe Value: 0.10000000149011612
# Closest action index: 0, Value: 0.3283006250858307, Goal Action: -1.25
# Step 53: Pstate: [1.27 0.37 0.1 ], Goal: -1.63, Action: -1.25, Dist: 0.38, Safe Value: 0.1899999976158142
# Closest action index: 0, Value: 0.3231634795665741, Goal Action: -1.25
# Step 54: Pstate: [1.32 0.38 0.03], Goal: -1.76, Action: -1.25, Dist: 0.4, Safe Value: 0.23000000417232513
# Closest action index: 0, Value: 0.2563530206680298, Goal Action: -1.25
# Step 55: Pstate: [ 1.37  0.38 -0.03], Goal: -1.88, Action: -1.25, Dist: 0.42, Safe Value: 0.23000000417232513
# Closest action index: 0, Value: 0.22259601950645447, Goal Action: -1.25
# Step 56: Pstate: [ 1.42  0.38 -0.09], Goal: -1.99, Action: -1.25, Dist: 0.44, Safe Value: 0.23000000417232513
# Closest action index: 0, Value: 0.20787940919399261, Goal Action: -1.25
# Step 57: Pstate: [ 1.47  0.37 -0.15], Goal: -2.1, Action: -1.25, Dist: 0.46, Safe Value: 0.23000000417232513
# Closest action index: 0, Value: 0.2071598768234253, Goal Action: -1.25
# Step 58: Pstate: [ 1.52  0.37 -0.22], Goal: -2.2, Action: -1.25, Dist: 0.49, Safe Value: 0.25
# Closest action index: 0, Value: 0.25409865379333496, Goal Action: -1.25
# Step 59: Pstate: [ 1.57  0.36 -0.28], Goal: -2.29, Action: -1.25, Dist: 0.51, Safe Value: 0.2800000011920929
# Closest action index: 34, Value: 0.24838800728321075, Goal Action: -1.25
# Step 60: Pstate: [ 1.62  0.34 -0.3 ], Goal: -2.37, Action: -0.4000000059604645, Dist: 0.54, Safe Value: 0.23000000417232513
# Closest action index: 1, Value: 0.21061667799949646, Goal Action: -1.25
# Step 61: Pstate: [ 1.66  0.33 -0.36], Goal: -2.45, Action: -1.2200000286102295, Dist: 0.57, Safe Value: 0.25999999046325684
# Closest action index: 0, Value: 0.25408509373664856, Goal Action: -1.25
# Step 62: Pstate: [ 1.71  0.31 -0.42], Goal: -2.53, Action: -1.25, Dist: 0.6, Safe Value: 0.30000001192092896
# Closest action index: 0, Value: 0.2992372512817383, Goal Action: -1.25
# Step 63: Pstate: [ 1.76  0.29 -0.49], Goal: -2.6, Action: -1.25, Dist: 0.63, Safe Value: 0.3400000035762787
# Closest action index: 0, Value: 0.335501492023468, Goal Action: -1.25
# Step 64: Pstate: [ 1.8   0.27 -0.55], Goal: -2.66, Action: -1.25, Dist: 0.66, Safe Value: 0.3700000047683716
# Closest action index: 0, Value: 0.3668883740901947, Goal Action: -1.25
# Step 65: Pstate: [ 1.84  0.24 -0.61], Goal: -2.72, Action: -1.25, Dist: 0.69, Safe Value: 0.4000000059604645
# Closest action index: 0, Value: 0.39543914794921875, Goal Action: -1.25
# Step 66: Pstate: [ 1.88  0.21 -0.67], Goal: -2.78, Action: -1.25, Dist: 0.72, Safe Value: 0.41999998688697815
# Closest action index: 0, Value: 0.4211929738521576, Goal Action: -1.25
# Step 67: Pstate: [ 1.92  0.18 -0.74], Goal: -2.84, Action: -1.25, Dist: 0.75, Safe Value: 0.44999998807907104
# Closest action index: 0, Value: 0.43393439054489136, Goal Action: -1.25
# Step 68: Pstate: [ 1.96  0.15 -0.8 ], Goal: -2.9, Action: -1.25, Dist: 0.77, Safe Value: 0.46000000834465027
# Closest action index: 0, Value: 0.4404814839363098, Goal Action: -1.25
# Step 69: Pstate: [ 2.    0.11 -0.86], Goal: -2.95, Action: -1.25, Dist: 0.8, Safe Value: 0.44999998807907104
# Closest action index: 0, Value: 0.43989306688308716, Goal Action: -1.25
# Step 70: Pstate: [ 2.03  0.07 -0.92], Goal: -3.0, Action: -1.25, Dist: 0.83, Safe Value: 0.44999998807907104
# Closest action index: 0, Value: 0.4341202974319458, Goal Action: -1.25
# Step 71: Pstate: [ 2.06  0.03 -0.99], Goal: -3.05, Action: -1.25, Dist: 0.86, Safe Value: 0.41999998688697815
# Closest action index: 0, Value: 0.416115403175354, Goal Action: -1.25
# Step 72: Pstate: [ 2.09 -0.01 -1.05], Goal: -3.1, Action: -1.25, Dist: 0.89, Safe Value: 0.38999998569488525
# Closest action index: 0, Value: 0.40003466606140137, Goal Action: -1.25
# Step 73: Pstate: [ 2.11 -0.05 -1.11], Goal: 3.13, Action: -1.25, Dist: 0.91, Safe Value: 0.38999998569488525
# Closest action index: 0, Value: 0.389055460691452, Goal Action: -1.25
# Step 74: Pstate: [ 2.13 -0.1  -1.17], Goal: 3.08, Action: -1.25, Dist: 0.94, Safe Value: 0.4099999964237213
# Closest action index: 0, Value: 0.3895193636417389, Goal Action: -1.25
# Step 75: Pstate: [ 2.15 -0.14 -1.24], Goal: 3.04, Action: -1.25, Dist: 0.96, Safe Value: 0.4000000059604645
# Closest action index: 0, Value: 0.39500147104263306, Goal Action: -1.25
# Step 76: Pstate: [ 2.17 -0.19 -1.3 ], Goal: 2.99, Action: -1.25, Dist: 0.99, Safe Value: 0.38999998569488525
# Closest action index: 0, Value: 0.39559707045555115, Goal Action: -1.25
# Step 77: Pstate: [ 2.18 -0.24 -1.36], Goal: 2.95, Action: -1.25, Dist: 1.01, Safe Value: 0.38999998569488525
# Closest action index: 0, Value: 0.3888152837753296, Goal Action: -1.25
# Step 78: Pstate: [ 2.19 -0.29 -1.42], Goal: 2.9, Action: -1.25, Dist: 1.03, Safe Value: 0.3799999952316284
# Closest action index: 0, Value: 0.37647348642349243, Goal Action: -1.25
# Step 79: Pstate: [ 2.2  -0.34 -1.49], Goal: 2.86, Action: -1.25, Dist: 1.06, Safe Value: 0.3700000047683716
# Closest action index: 0, Value: 0.35737144947052, Goal Action: -1.25
# Step 80: Pstate: [ 2.2  -0.39 -1.55], Goal: 2.82, Action: -1.25, Dist: 1.08, Safe Value: 0.3700000047683716
# Closest action index: 0, Value: 0.34233546257019043, Goal Action: -1.25
# Step 81: Pstate: [ 2.21 -0.44 -1.61], Goal: 2.77, Action: -1.25, Dist: 1.1, Safe Value: 0.36000001430511475
# Closest action index: 0, Value: 0.3621247708797455, Goal Action: -1.25
# Step 82: Pstate: [ 2.2  -0.49 -1.67], Goal: 2.73, Action: -1.25, Dist: 1.12, Safe Value: 0.3499999940395355
# Closest action index: 0, Value: 0.3676924705505371, Goal Action: -1.25
# Step 83: Pstate: [ 2.2  -0.54 -1.74], Goal: 2.69, Action: -1.25, Dist: 1.13, Safe Value: 0.3499999940395355
# Closest action index: 0, Value: 0.3617348372936249, Goal Action: -1.25
# Step 84: Pstate: [ 2.19 -0.59 -1.8 ], Goal: 2.65, Action: -1.25, Dist: 1.15, Safe Value: 0.3400000035762787
# Closest action index: 0, Value: 0.36112508177757263, Goal Action: -1.25
# Step 85: Pstate: [ 2.18 -0.63 -1.86], Goal: 2.61, Action: -1.25, Dist: 1.17, Safe Value: 0.3400000035762787
# Closest action index: 0, Value: 0.38305962085723877, Goal Action: -1.25
# Step 86: Pstate: [ 2.16 -0.68 -1.92], Goal: 2.57, Action: -1.25, Dist: 1.18, Safe Value: 0.33000001311302185
# Closest action index: 0, Value: 0.39748212695121765, Goal Action: -1.25
# Step 87: Pstate: [ 2.15 -0.73 -1.99], Goal: 2.53, Action: -1.25, Dist: 1.2, Safe Value: 0.3199999928474426
# Closest action index: 0, Value: 0.3955446481704712, Goal Action: -1.25
# Step 88: Pstate: [ 2.13 -0.77 -2.05], Goal: 2.49, Action: -1.25, Dist: 1.21, Safe Value: 0.3199999928474426
# Closest action index: 0, Value: 0.371126264333725, Goal Action: -1.25
# Step 89: Pstate: [ 2.1  -0.82 -2.11], Goal: 2.45, Action: -1.25, Dist: 1.22, Safe Value: 0.3100000023841858
# Closest action index: 0, Value: 0.35269680619239807, Goal Action: -1.25
# Step 90: Pstate: [ 2.08 -0.86 -2.17], Goal: 2.41, Action: -1.25, Dist: 1.23, Safe Value: 0.3100000023841858
# Closest action index: 0, Value: 0.33233559131622314, Goal Action: -1.25
# Step 91: Pstate: [ 2.05 -0.9  -2.24], Goal: 2.37, Action: -1.25, Dist: 1.24, Safe Value: 0.3199999928474426
# Closest action index: 0, Value: 0.3413234055042267, Goal Action: -1.25
# Step 92: Pstate: [ 2.02 -0.94 -2.3 ], Goal: 2.33, Action: -1.25, Dist: 1.25, Safe Value: 0.3199999928474426
# Closest action index: 0, Value: 0.3428104519844055, Goal Action: -1.25
# Step 93: Pstate: [ 1.99 -0.98 -2.36], Goal: 2.29, Action: -1.25, Dist: 1.26, Safe Value: 0.3400000035762787
# Closest action index: 0, Value: 0.35715049505233765, Goal Action: -1.25
# Step 94: Pstate: [ 1.95 -1.02 -2.42], Goal: 2.25, Action: -1.25, Dist: 1.26, Safe Value: 0.3499999940395355
# Closest action index: 0, Value: 0.38131558895111084, Goal Action: -1.25
# Step 95: Pstate: [ 1.91 -1.05 -2.49], Goal: 2.21, Action: -1.25, Dist: 1.27, Safe Value: 0.36000001430511475
# Closest action index: 0, Value: 0.40448909997940063, Goal Action: -1.25
# Step 96: Pstate: [ 1.87 -1.08 -2.55], Goal: 2.17, Action: -1.25, Dist: 1.27, Safe Value: 0.3799999952316284
# Closest action index: 0, Value: 0.4519241452217102, Goal Action: -1.25
# Step 97: Pstate: [ 1.83 -1.11 -2.61], Goal: 2.13, Action: -1.25, Dist: 1.27, Safe Value: 0.38999998569488525
# Closest action index: 0, Value: 0.43127012252807617, Goal Action: -1.25
# Step 98: Pstate: [ 1.79 -1.13 -2.67], Goal: 2.09, Action: -1.25, Dist: 1.28, Safe Value: 0.4300000071525574
# Closest action index: 0, Value: 0.4283697307109833, Goal Action: -1.25
# Step 99: Pstate: [ 1.74 -1.15 -2.74], Goal: 2.05, Action: -1.25, Dist: 1.28, Safe Value: 0.4399999976158142
# Closest action index: 0, Value: 0.4360392093658447, Goal Action: -1.25
# Step 100: Pstate: [ 1.7  -1.17 -2.8 ], Goal: 2.01, Action: -1.25, Dist: 1.28, Safe Value: 0.44999998807907104

# %% [markdown]
# ## LRSF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.2
simlen = 1000

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])    
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()    
    curr_safe = 1 

    if safe_value < epsilon: 
        safe_action = brt.find_a(feat.detach().cpu().numpy())
        action = safe_action[0]
        curr_safe = 0 # when safe action is engaged
        print(Fore.RED + 'Safe action engaged!' + Style.RESET_ALL)
    else:
        action = goal_act # nominal action otherwise
    
    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    
    demo, priv_state = dubin_env.forward(action) # take action in real
    feat = brt.data_to_feat(demo, action=action) # take action 
    Vz = brt.evaluate_V(to_np(feat))[0]
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action
    
    safe_values.append(safe_value)
    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])

    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 3)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)
col = np.where(np.array(current_safe) == 1, 'blue', 'red')
plt.scatter(pss[:,0], pss[:,1], c=col, s=10, label='Trajectory')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()
    
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='CBF Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 27002886 variables.
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.3700000047683716
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.3440000116825104
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.3610000014305115
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.3869999945163727
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.4099999964237213
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.4480000138282776
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.47699999809265137
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.4909999966621399
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.4740000069141388
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.4099999964237213
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.3230000138282776
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.26899999380111694
# Step 13: Pstate: [-1.07  0.66 -0.76], Goal: -0.32, Action: 1.25, Dist: 2.17, Safe Value: 0.23000000417232513
# Step 14: Pstate: [-1.03  0.63 -0.7 ], Goal: -0.31, Action: 1.25, Dist: 2.13, Safe Value: 0.19900000095367432
# Safe action engaged!
# Step 15: Pstate: [-0.99  0.6  -0.76], Goal: -0.3, Action: -1.25, Dist: 2.08, Safe Value: 0.20600000023841858
# Step 16: Pstate: [-0.96  0.56 -0.7 ], Goal: -0.29, Action: 1.25, Dist: 2.04, Safe Value: 0.15199999511241913
# Safe action engaged!
# Step 17: Pstate: [-0.92  0.53 -0.76], Goal: -0.28, Action: -1.25, Dist: 1.99, Safe Value: 0.1979999989271164
# Safe action engaged!
# Step 18: Pstate: [-0.88  0.49 -0.82], Goal: -0.27, Action: -1.25, Dist: 1.95, Safe Value: 0.2370000034570694
# Step 19: Pstate: [-0.85  0.46 -0.76], Goal: -0.26, Action: 1.25, Dist: 1.9, Safe Value: 0.1459999978542328
# Safe action engaged!
# Step 20: Pstate: [-0.81  0.42 -0.82], Goal: -0.24, Action: -1.25, Dist: 1.86, Safe Value: 0.1809999942779541
# Safe action engaged!
# Step 21: Pstate: [-0.78  0.39 -0.88], Goal: -0.23, Action: -1.25, Dist: 1.82, Safe Value: 0.20900000631809235
# Step 22: Pstate: [-0.75  0.35 -0.82], Goal: -0.21, Action: 1.25, Dist: 1.78, Safe Value: 0.21699999272823334
# Step 23: Pstate: [-0.71  0.31 -0.76], Goal: -0.2, Action: 1.25, Dist: 1.74, Safe Value: 0.4099999964237213
# Step 24: Pstate: [-0.68  0.28 -0.7 ], Goal: -0.18, Action: 1.25, Dist: 1.7, Safe Value: 0.41600000858306885
# Step 25: Pstate: [-0.64  0.25 -0.63], Goal: -0.16, Action: 1.25, Dist: 1.66, Safe Value: 0.42500001192092896
# Step 26: Pstate: [-0.6   0.22 -0.57], Goal: -0.15, Action: 1.25, Dist: 1.61, Safe Value: 0.4359999895095825
# Step 27: Pstate: [-0.56  0.19 -0.51], Goal: -0.13, Action: 1.25, Dist: 1.57, Safe Value: 0.3919999897480011
# Step 28: Pstate: [-0.51  0.16 -0.45], Goal: -0.12, Action: 1.25, Dist: 1.52, Safe Value: 0.41100001335144043
# Step 29: Pstate: [-0.47  0.14 -0.38], Goal: -0.11, Action: 1.25, Dist: 1.47, Safe Value: 0.4309999942779541
# Step 30: Pstate: [-0.42  0.12 -0.32], Goal: -0.1, Action: 1.25, Dist: 1.43, Safe Value: 0.453000009059906
# Step 31: Pstate: [-0.37  0.11 -0.26], Goal: -0.09, Action: 1.25, Dist: 1.38, Safe Value: 0.4519999921321869
# Step 32: Pstate: [-0.32  0.1  -0.2 ], Goal: -0.08, Action: 1.25, Dist: 1.33, Safe Value: 0.45399999618530273
# Step 33: Pstate: [-0.28  0.09 -0.13], Goal: -0.07, Action: 1.25, Dist: 1.28, Safe Value: 0.4410000145435333
# Step 34: Pstate: [-0.23  0.08 -0.07], Goal: -0.07, Action: 1.25, Dist: 1.23, Safe Value: 0.4169999957084656
# Step 35: Pstate: [-0.18  0.08 -0.06], Goal: -0.06, Action: 0.13, Dist: 1.18, Safe Value: 0.41100001335144043
# Step 36: Pstate: [-0.13  0.07 -0.06], Goal: -0.06, Action: 0.01, Dist: 1.13, Safe Value: 0.3720000088214874
# Step 37: Pstate: [-0.08  0.07 -0.06], Goal: -0.06, Action: 0.0, Dist: 1.08, Safe Value: 0.3499999940395355
# Step 38: Pstate: [-0.03  0.07 -0.06], Goal: -0.06, Action: 0.0, Dist: 1.03, Safe Value: 0.3240000009536743
# Step 39: Pstate: [ 0.02  0.06 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.98, Safe Value: 0.3529999852180481
# Step 40: Pstate: [ 0.07  0.06 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.93, Safe Value: 0.3720000088214874
# Step 41: Pstate: [ 0.12  0.06 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.88, Safe Value: 0.42800000309944153
# Step 42: Pstate: [ 0.17  0.05 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.83, Safe Value: 0.44999998807907104
# Step 43: Pstate: [ 0.22  0.05 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.78, Safe Value: 0.46299999952316284
# Step 44: Pstate: [ 0.27  0.05 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.73, Safe Value: 0.45100000500679016
# Step 45: Pstate: [ 0.32  0.04 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.68, Safe Value: 0.43700000643730164
# Step 46: Pstate: [ 0.37  0.04 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.63, Safe Value: 0.4359999895095825
# Step 47: Pstate: [ 0.42  0.04 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.58, Safe Value: 0.44699999690055847
# Step 48: Pstate: [ 0.47  0.03 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.53, Safe Value: 0.4749999940395355
# Step 49: Pstate: [ 0.52  0.03 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.48, Safe Value: 0.5019999742507935
# Step 50: Pstate: [ 0.57  0.03 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.43, Safe Value: 0.5329999923706055
# Step 51: Pstate: [ 0.62  0.02 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.38, Safe Value: 0.5699999928474426
# Step 52: Pstate: [ 0.67  0.02 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.33, Safe Value: 0.6150000095367432
# Step 53: Pstate: [ 0.72  0.02 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.28, Safe Value: 0.6370000243186951
# Step 54: Pstate: [ 0.77  0.01 -0.06], Goal: -0.06, Action: -0.0, Dist: 0.23, Safe Value: 0.652999997138977
# Step 55: Pstate: [ 0.82  0.01 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.18, Safe Value: 0.6669999957084656
# Step 56: Pstate: [ 0.87  0.01 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.13, Safe Value: 0.6660000085830688
# Step 57: Pstate: [ 0.92  0.01 -0.06], Goal: -0.06, Action: 0.0, Dist: 0.08, Safe Value: 0.6600000262260437
# Step 58: Pstate: [ 0.97  0.   -0.06], Goal: -0.06, Action: 0.0, Dist: 0.03, Safe Value: 0.6710000038146973
# Reached the goal!
