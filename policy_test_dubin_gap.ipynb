# %%
from latent_dubins_gap import LatentDubinGap, get_args, state_to_image_pil_hq
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from colorama import Fore, Back, Style

class DubinEnv():
    def __init__(self, start_state, goal_state):
        self.start_state = start_state
        self.curr_state = start_state
        self.goal_state = goal_state
        self.args = get_args()
        self.v = self.args.speed
        self.dt = self.args.dt

    def forward(self, action):
        # Apply the action to the current state
        state_obs, img_obs, state_gt, dones, acs = ([] for _ in range(5))
        pstate = self.curr_state.copy()
        pstate[0] += self.v * np.cos(self.curr_state[2]) * self.dt
        pstate[1] += self.v * np.sin(self.curr_state[2]) * self.dt
        pstate[2] += action * self.dt  # Update the heading angle
        img = state_to_image_pil_hq(pstate, self.args)

        state_obs.append(pstate[2]) # get to observe theta
        state_gt.append(pstate) # gt state
        dones.append(1)
        acs.append(action)
        img_obs.append(img)

        demo = {}
        demo['obs'] = {'image': img_obs, 'state': state_obs, 'priv_state': state_gt}
        demo['actions'] = acs
        demo['dones'] = dones
        return demo, pstate
    
    def goal_ref(self):
        # Calculate the direction towards the goal
        dx = self.goal_state[0] - self.curr_state[0]
        dy = self.goal_state[1] - self.curr_state[1]
        angle_to_goal = np.arctan2(dy, dx)
        ref_theta = angle_to_goal
        delta_theta = ref_theta - self.curr_state[2]
        # Normalize the angle to be within [-pi, pi] using modulo operation
        delta_theta = (delta_theta + np.pi) % (2 * np.pi) - np.pi
        ref_theta_dot = (delta_theta) / self.dt

        return ref_theta, np.clip(ref_theta_dot, -self.args.turnRate, self.args.turnRate)

to_np = lambda x: x.cpu().detach().numpy()
# Out:
# /home/clown2/Desktop/Work/Research/wm_cbf

# %% [markdown]
# ## CBF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.2
gamma = 0.9
simlen = 100
u_min = -dubin_env.args.turnRate
u_max = dubin_env.args.turnRate
u_samples = 100
u_delta = (u_max - u_min) / u_samples
u_range = np.arange(u_min, u_max + u_delta, u_delta)  # action range for Dubins car
u_range = torch.tensor(u_range, dtype=torch.float32, device=brt.args.device).unsqueeze(-1)  # Convert to tensor

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()
    curr_safe = 1 

    Qzs = brt.evaluate_Q(to_np(feat), u_range)
    # print(f"Qzs: {Qzs}")
    cbf_cond = Qzs > gamma * Vz
    # print(f"CBF Condition: {cbf_cond}")
    Qzs_valid_idx = np.where(cbf_cond)[0]
    # print(f"u_range: {u_range.squeeze(-1).detach().cpu().numpy()}")

    if Qzs_valid_idx.size == 0:
        print(Fore.RED + "No valid actions found, using goal action."+Style.RESET_ALL)
        action = goal_act
    else:
        # Find the action that maximizes the Q-value while satisfying the CBF condition
        Qzs_valid = Qzs[Qzs_valid_idx]
        # Find the action that minimizes the distance to the goal action
        affordable_actions = torch.abs(u_range.squeeze(-1).masked_fill(torch.tensor(~cbf_cond, device=u_range.device), torch.inf) - goal_act)
        # print(f"Affordable actions: {affordable_actions}")
        closest_action = torch.argmin(affordable_actions)
        print(f"Closest action index: {closest_action}, Value: {Qzs[closest_action]}, Goal Action: {goal_act}")
        action = u_range[closest_action][0].detach().cpu().numpy()

    # demo, priv_state = dubin_env.forward(action)
    # feat = brt.data_to_feat(demo)
    # Vz = brt.evaluate_V(to_np(feat))[0]
    # Lz = brt.margin_fn(feat)[0][0][0]
    # Vz = np.min([Vz, to_np(Lz)])
    # safe_value = Vz = np.min([Vz, to_np(Lz)])
    # dubin_env.curr_state = priv_state  # Update the current state in the environment

    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action

    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    safe_values.append(safe_value)

    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])
    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 2)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break


# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
# circle = patches.Circle((0,0), 0.5, edgecolor=(1,0,0), facecolor='none')
# ax.add_patch(circle)

for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)

col = np.where(np.array(current_safe) == 1, 'blue', 'red')
plt.scatter(pss[:,0], pss[:,1], c=col, s=10, label='Trajectory')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()

# plot safe value over time
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='CBF Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 27002886 variables.
# Closest action index: 100, Value: 0.41640591621398926, Goal Action: 1.25
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.4000000059604645
# Closest action index: 100, Value: 0.41640591621398926, Goal Action: 1.25
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.3700000047683716
# Closest action index: 100, Value: 0.42993679642677307, Goal Action: 1.25
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.3400000035762787
# Closest action index: 100, Value: 0.4409749507904053, Goal Action: 1.25
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.36000001430511475
# Closest action index: 100, Value: 0.44169026613235474, Goal Action: 1.25
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.38999998569488525
# Closest action index: 100, Value: 0.4667881429195404, Goal Action: 1.25
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.4099999964237213
# Closest action index: 100, Value: 0.4865555763244629, Goal Action: 1.25
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.44999998807907104
# Closest action index: 100, Value: 0.5108343958854675, Goal Action: 1.25
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.47999998927116394
# Closest action index: 100, Value: 0.5367027521133423, Goal Action: 1.25
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.49000000953674316
# Closest action index: 100, Value: 0.5257014632225037, Goal Action: 1.25
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.4699999988079071
# Closest action index: 100, Value: 0.49315255880355835, Goal Action: 1.25
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.4099999964237213
# Closest action index: 100, Value: 0.39395833015441895, Goal Action: 1.25
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.3199999928474426
# Closest action index: 94, Value: 0.2907538414001465, Goal Action: 1.25
# Step 13: Pstate: [-1.07  0.66 -0.77], Goal: -0.32, Action: 1.100000023841858, Dist: 2.17, Safe Value: 0.27000001072883606
# Closest action index: 75, Value: 0.2432047426700592, Goal Action: 1.25
# Step 14: Pstate: [-1.03  0.63 -0.73], Goal: -0.31, Action: 0.6200000047683716, Dist: 2.13, Safe Value: 0.23000000417232513
# Closest action index: 100, Value: 0.20987357199192047, Goal Action: 1.25
# Step 15: Pstate: [-1.    0.59 -0.67], Goal: -0.3, Action: 1.25, Dist: 2.08, Safe Value: 0.20999999344348907
# Closest action index: 100, Value: 0.2117055058479309, Goal Action: 1.25
# Step 16: Pstate: [-0.96  0.56 -0.61], Goal: -0.29, Action: 1.25, Dist: 2.04, Safe Value: 0.17000000178813934
# Closest action index: 100, Value: 0.2047882080078125, Goal Action: 1.25
# Step 17: Pstate: [-0.92  0.53 -0.55], Goal: -0.28, Action: 1.25, Dist: 1.99, Safe Value: 0.11999999731779099
# Closest action index: 100, Value: 0.14932315051555634, Goal Action: 1.25
# Step 18: Pstate: [-0.87  0.51 -0.48], Goal: -0.27, Action: 1.25, Dist: 1.94, Safe Value: 0.10000000149011612
# Closest action index: 100, Value: 0.1422559916973114, Goal Action: 1.25
# Step 19: Pstate: [-0.83  0.48 -0.42], Goal: -0.26, Action: 1.25, Dist: 1.89, Safe Value: 0.1599999964237213
# Closest action index: 82, Value: 0.14268353581428528, Goal Action: 1.25
# Step 20: Pstate: [-0.78  0.46 -0.38], Goal: -0.26, Action: 0.800000011920929, Dist: 1.84, Safe Value: 0.20999999344348907
# Closest action index: 52, Value: 0.19068552553653717, Goal Action: 1.25
# Step 21: Pstate: [-0.74  0.45 -0.38], Goal: -0.25, Action: 0.05000000074505806, Dist: 1.79, Safe Value: 0.20999999344348907
# Closest action index: 13, Value: 0.19229726493358612, Goal Action: 1.25
# Step 22: Pstate: [-0.69  0.43 -0.43], Goal: -0.25, Action: -0.9200000166893005, Dist: 1.74, Safe Value: 0.23999999463558197
# Closest action index: 14, Value: 0.21934320032596588, Goal Action: 1.25
# Step 23: Pstate: [-0.64  0.41 -0.47], Goal: -0.25, Action: -0.8999999761581421, Dist: 1.69, Safe Value: 0.30000001192092896
# Closest action index: 16, Value: 0.2720755636692047, Goal Action: 1.25
# Step 24: Pstate: [-0.6   0.38 -0.51], Goal: -0.24, Action: -0.8500000238418579, Dist: 1.64, Safe Value: 0.3100000023841858
# Closest action index: 15, Value: 0.2785518765449524, Goal Action: 1.25
# Step 25: Pstate: [-0.56  0.36 -0.56], Goal: -0.24, Action: -0.8799999952316284, Dist: 1.6, Safe Value: 0.28999999165534973
# Closest action index: 23, Value: 0.26115989685058594, Goal Action: 1.25
# Step 26: Pstate: [-0.51  0.33 -0.59], Goal: -0.23, Action: -0.6800000071525574, Dist: 1.55, Safe Value: 0.2199999988079071
# Closest action index: 35, Value: 0.20198756456375122, Goal Action: 1.25
# Step 27: Pstate: [-0.47  0.3  -0.61], Goal: -0.22, Action: -0.3799999952316284, Dist: 1.5, Safe Value: 0.18000000715255737
# Closest action index: 39, Value: 0.1659124195575714, Goal Action: 1.25
# Step 28: Pstate: [-0.43  0.28 -0.62], Goal: -0.2, Action: -0.2800000011920929, Dist: 1.46, Safe Value: 0.18000000715255737
# Closest action index: 55, Value: 0.16203968226909637, Goal Action: 1.25
# Step 29: Pstate: [-0.39  0.25 -0.62], Goal: -0.19, Action: 0.11999999731779099, Dist: 1.41, Safe Value: 0.18000000715255737
# Closest action index: 52, Value: 0.16092310845851898, Goal Action: 1.25
# Step 30: Pstate: [-0.35  0.22 -0.61], Goal: -0.18, Action: 0.05000000074505806, Dist: 1.37, Safe Value: 0.2199999988079071
# Closest action index: 40, Value: 0.19427675008773804, Goal Action: 1.25
# Step 31: Pstate: [-0.31  0.19 -0.63], Goal: -0.16, Action: -0.25, Dist: 1.32, Safe Value: 0.23000000417232513
# Closest action index: 71, Value: 0.20739908516407013, Goal Action: 1.25
# Step 32: Pstate: [-0.27  0.16 -0.6 ], Goal: -0.14, Action: 0.5199999809265137, Dist: 1.28, Safe Value: 0.23999999463558197
# Closest action index: 100, Value: 0.2544715702533722, Goal Action: 1.25
# Step 33: Pstate: [-0.23  0.13 -0.54], Goal: -0.13, Action: 1.25, Dist: 1.23, Safe Value: 0.25
# Closest action index: 100, Value: 0.2800746560096741, Goal Action: 1.25
# Step 34: Pstate: [-0.18  0.11 -0.48], Goal: -0.11, Action: 1.25, Dist: 1.19, Safe Value: 0.2800000011920929
# Closest action index: 100, Value: 0.3267211318016052, Goal Action: 1.25
# Step 35: Pstate: [-0.14  0.08 -0.41], Goal: -0.09, Action: 1.25, Dist: 1.14, Safe Value: 0.3100000023841858
# Closest action index: 100, Value: 0.3640941381454468, Goal Action: 1.25
# Step 36: Pstate: [-0.09  0.06 -0.35], Goal: -0.07, Action: 1.25, Dist: 1.1, Safe Value: 0.3400000035762787
# Closest action index: 100, Value: 0.3802981376647949, Goal Action: 1.25
# Step 37: Pstate: [-0.05  0.05 -0.29], Goal: -0.06, Action: 1.25, Dist: 1.05, Safe Value: 0.3799999952316284
# Closest action index: 100, Value: 0.41640833020210266, Goal Action: 1.25
# Step 38: Pstate: [ 0.    0.03 -0.23], Goal: -0.04, Action: 1.25, Dist: 1.0, Safe Value: 0.38999998569488525
# Closest action index: 100, Value: 0.43394944071769714, Goal Action: 1.25
# Step 39: Pstate: [ 0.05  0.02 -0.16], Goal: -0.03, Action: 1.25, Dist: 0.95, Safe Value: 0.4099999964237213
# Closest action index: 93, Value: 0.4234989881515503, Goal Action: 1.25
# Step 40: Pstate: [ 0.1   0.01 -0.11], Goal: -0.02, Action: 1.0800000429153442, Dist: 0.9, Safe Value: 0.4399999976158142
# Closest action index: 90, Value: 0.4311741590499878, Goal Action: 1.25
# Step 41: Pstate: [ 0.15  0.01 -0.06], Goal: -0.01, Action: 1.0, Dist: 0.85, Safe Value: 0.4699999988079071
# Closest action index: 91, Value: 0.4690845310688019, Goal Action: 1.0368829591348838
# Step 42: Pstate: [ 0.2   0.   -0.01], Goal: -0.01, Action: 1.0199999809265137, Dist: 0.8, Safe Value: 0.4699999988079071
# Closest action index: 53, Value: 0.5345684289932251, Goal Action: 0.07654528620583356
# Step 43: Pstate: [ 0.25  0.   -0.  ], Goal: -0.0, Action: 0.07999999821186066, Dist: 0.75, Safe Value: 0.4699999988079071
# Closest action index: 50, Value: 0.5269491672515869, Goal Action: 0.006638711569371125
# Step 44: Pstate: [ 0.3  0.  -0. ], Goal: -0.0, Action: -0.0, Dist: 0.7, Safe Value: 0.47999998927116394
# Closest action index: 50, Value: 0.5271153450012207, Goal Action: 0.007111951733715927
# Step 45: Pstate: [ 0.35  0.   -0.  ], Goal: -0.0, Action: -0.0, Dist: 0.65, Safe Value: 0.49000000953674316
# Closest action index: 50, Value: 0.5336697101593018, Goal Action: 0.007657840436179342
# Step 46: Pstate: [ 0.4  0.  -0. ], Goal: -0.0, Action: -0.0, Dist: 0.6, Safe Value: 0.4699999988079071
# Closest action index: 50, Value: 0.543122410774231, Goal Action: 0.008294497215945995
# Step 47: Pstate: [ 0.45  0.   -0.  ], Goal: -0.0, Action: -0.0, Dist: 0.55, Safe Value: 0.49000000953674316
# Closest action index: 50, Value: 0.5614733695983887, Goal Action: 0.009046613680983029
# Step 48: Pstate: [ 0.5  0.  -0. ], Goal: -0.0, Action: -0.0, Dist: 0.5, Safe Value: 0.5
# Closest action index: 50, Value: 0.572786271572113, Goal Action: 0.009948730298212638
# Step 49: Pstate: [ 0.55  0.   -0.  ], Goal: -0.0, Action: -0.0, Dist: 0.45, Safe Value: 0.5299999713897705
# Closest action index: 50, Value: 0.5768427848815918, Goal Action: 0.011050690884184533
# Step 50: Pstate: [ 0.6  0.  -0. ], Goal: -0.0, Action: -0.0, Dist: 0.4, Safe Value: 0.550000011920929
# Closest action index: 50, Value: 0.5947500467300415, Goal Action: 0.012427173587541418
# Step 51: Pstate: [ 0.65  0.   -0.  ], Goal: -0.0, Action: -0.0, Dist: 0.35, Safe Value: 0.5699999928474426
# Closest action index: 51, Value: 0.6293069124221802, Goal Action: 0.014195358491031485
# Step 52: Pstate: [ 0.7  0.  -0. ], Goal: -0.0, Action: 0.019999999552965164, Dist: 0.3, Safe Value: 0.6000000238418579
# Closest action index: 50, Value: 0.6450735926628113, Goal Action: -0.008449820246907436
# Step 53: Pstate: [ 0.75  0.   -0.  ], Goal: -0.0, Action: -0.0, Dist: 0.25, Safe Value: 0.6200000047683716
# Closest action index: 50, Value: 0.6542513966560364, Goal Action: -0.010130303211726144
# Step 54: Pstate: [ 0.8  0.  -0. ], Goal: -0.0, Action: -0.0, Dist: 0.2, Safe Value: 0.6299999952316284
# Closest action index: 49, Value: 0.6543503999710083, Goal Action: -0.012645143367251421
# Step 55: Pstate: [ 0.85  0.   -0.  ], Goal: -0.0, Action: -0.019999999552965164, Dist: 0.15, Safe Value: 0.6499999761581421
# Closest action index: 50, Value: 0.6464616060256958, Goal Action: 0.008179075297034544
# Step 56: Pstate: [ 0.9  0.  -0. ], Goal: -0.0, Action: -0.0, Dist: 0.1, Safe Value: 0.6600000262260437
# Closest action index: 50, Value: 0.6410667896270752, Goal Action: 0.01221173260874231
# Step 57: Pstate: [ 0.95  0.   -0.  ], Goal: -0.0, Action: -0.0, Dist: 0.05, Safe Value: 0.6700000166893005
# Closest action index: 51, Value: 0.6518372893333435, Goal Action: 0.024088421654662184
# Step 58: Pstate: [ 1. -0. -0.], Goal: -0.0, Action: 0.019999999552965164, Dist: 0.0, Safe Value: 0.6700000166893005
# Reached the goal!

# %% [markdown]
# ## LRSF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.2
simlen = 1000

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()    
    curr_safe = 1 

    if safe_value < epsilon: 
        safe_action = brt.find_a(feat.detach().cpu().numpy())
        action = safe_action[0]
        curr_safe = 0 # when safe action is engaged
        print(Fore.RED + 'Safe action engaged!' + Style.RESET_ALL)
    else:
        action = goal_act # nominal action otherwise
    
    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    
    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action
    
    safe_values.append(safe_value)
    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])

    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 3)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)
col = np.where(np.array(current_safe) == 1, 'blue', 'red')
plt.scatter(pss[:,0], pss[:,1], c=col, s=10, label='Trajectory')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()
    
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='Safety Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 27002886 variables.
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.40299999713897705
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.3700000047683716
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.3440000116825104
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.3610000014305115
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.3869999945163727
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.4099999964237213
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.4480000138282776
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.47699999809265137
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.4909999966621399
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.4740000069141388
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.4099999964237213
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.3230000138282776
# Step 13: Pstate: [-1.07  0.66 -0.76], Goal: -0.32, Action: 1.25, Dist: 2.17, Safe Value: 0.26899999380111694
# Step 14: Pstate: [-1.03  0.63 -0.7 ], Goal: -0.31, Action: 1.25, Dist: 2.13, Safe Value: 0.23000000417232513
# Step 15: Pstate: [-0.99  0.6  -0.63], Goal: -0.3, Action: 1.25, Dist: 2.08, Safe Value: 0.19900000095367432
# Safe action engaged!
# Step 16: Pstate: [-0.95  0.57 -0.7 ], Goal: -0.29, Action: -1.25, Dist: 2.03, Safe Value: 0.14900000393390656
# Safe action engaged!
# Step 17: Pstate: [-0.92  0.53 -0.76], Goal: -0.28, Action: -1.25, Dist: 1.99, Safe Value: 0.15700000524520874
# Safe action engaged!
# Step 18: Pstate: [-0.88  0.5  -0.82], Goal: -0.27, Action: -1.25, Dist: 1.94, Safe Value: 0.20000000298023224
# Safe action engaged!
# Step 19: Pstate: [-0.84  0.46 -0.88], Goal: -0.26, Action: -1.25, Dist: 1.9, Safe Value: 0.23199999332427979
# Step 20: Pstate: [-0.81  0.42 -0.82], Goal: -0.25, Action: 1.25, Dist: 1.86, Safe Value: 0.26600000262260437
# Step 21: Pstate: [-0.78  0.39 -0.76], Goal: -0.23, Action: 1.25, Dist: 1.82, Safe Value: 0.1809999942779541
# Safe action engaged!
# Step 22: Pstate: [-0.74  0.35 -0.82], Goal: -0.21, Action: -1.25, Dist: 1.78, Safe Value: 0.23999999463558197
# Step 23: Pstate: [-0.71  0.32 -0.76], Goal: -0.2, Action: 1.25, Dist: 1.74, Safe Value: 0.2590000033378601
# Step 24: Pstate: [-0.67  0.28 -0.7 ], Goal: -0.18, Action: 1.25, Dist: 1.7, Safe Value: 0.40700000524520874
# Step 25: Pstate: [-0.63  0.25 -0.63], Goal: -0.17, Action: 1.25, Dist: 1.65, Safe Value: 0.41999998688697815
# Step 26: Pstate: [-0.59  0.22 -0.57], Goal: -0.15, Action: 1.25, Dist: 1.61, Safe Value: 0.42800000309944153
# Step 27: Pstate: [-0.55  0.19 -0.51], Goal: -0.14, Action: 1.25, Dist: 1.56, Safe Value: 0.4350000023841858
# Step 28: Pstate: [-0.51  0.17 -0.45], Goal: -0.12, Action: 1.25, Dist: 1.52, Safe Value: 0.3919999897480011
# Step 29: Pstate: [-0.46  0.15 -0.38], Goal: -0.11, Action: 1.25, Dist: 1.47, Safe Value: 0.41200000047683716
# Step 30: Pstate: [-0.42  0.13 -0.32], Goal: -0.1, Action: 1.25, Dist: 1.42, Safe Value: 0.43299999833106995
# Step 31: Pstate: [-0.37  0.11 -0.26], Goal: -0.09, Action: 1.25, Dist: 1.37, Safe Value: 0.453000009059906
# Step 32: Pstate: [-0.32  0.1  -0.2 ], Goal: -0.08, Action: 1.25, Dist: 1.32, Safe Value: 0.43700000643730164
# Step 33: Pstate: [-0.27  0.09 -0.13], Goal: -0.08, Action: 1.25, Dist: 1.27, Safe Value: 0.43799999356269836
# Step 34: Pstate: [-0.22  0.08 -0.07], Goal: -0.07, Action: 1.25, Dist: 1.22, Safe Value: 0.4309999942779541
# Step 35: Pstate: [-0.17  0.08 -0.07], Goal: -0.07, Action: 0.05, Dist: 1.17, Safe Value: 0.39899998903274536
# Step 36: Pstate: [-0.12  0.08 -0.07], Goal: -0.07, Action: 0.0, Dist: 1.12, Safe Value: 0.3889999985694885
# Step 37: Pstate: [-0.07  0.07 -0.07], Goal: -0.07, Action: 0.0, Dist: 1.07, Safe Value: 0.34599998593330383
# Step 38: Pstate: [-0.02  0.07 -0.07], Goal: -0.07, Action: 0.0, Dist: 1.02, Safe Value: 0.33399999141693115
# Step 39: Pstate: [ 0.03  0.07 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.97, Safe Value: 0.3240000009536743
# Step 40: Pstate: [ 0.08  0.06 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.92, Safe Value: 0.335999995470047
# Step 41: Pstate: [ 0.13  0.06 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.87, Safe Value: 0.37599998712539673
# Step 42: Pstate: [ 0.18  0.06 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.82, Safe Value: 0.4129999876022339
# Step 43: Pstate: [ 0.23  0.05 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.77, Safe Value: 0.4519999921321869
# Step 44: Pstate: [ 0.28  0.05 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.72, Safe Value: 0.4580000042915344
# Step 45: Pstate: [ 0.33  0.05 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.67, Safe Value: 0.44200000166893005
# Step 46: Pstate: [ 0.38  0.04 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.62, Safe Value: 0.43700000643730164
# Step 47: Pstate: [ 0.43  0.04 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.57, Safe Value: 0.42899999022483826
# Step 48: Pstate: [ 0.48  0.04 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.52, Safe Value: 0.44699999690055847
# Step 49: Pstate: [ 0.53  0.03 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.47, Safe Value: 0.47099998593330383
# Step 50: Pstate: [ 0.58  0.03 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.42, Safe Value: 0.5019999742507935
# Step 51: Pstate: [ 0.63  0.03 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.37, Safe Value: 0.5360000133514404
# Step 52: Pstate: [ 0.68  0.02 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.32, Safe Value: 0.5690000057220459
# Step 53: Pstate: [ 0.73  0.02 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.27, Safe Value: 0.6190000176429749
# Step 54: Pstate: [ 0.78  0.02 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.22, Safe Value: 0.6380000114440918
# Step 55: Pstate: [ 0.83  0.01 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.17, Safe Value: 0.656000018119812
# Step 56: Pstate: [ 0.88  0.01 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.12, Safe Value: 0.6660000085830688
# Step 57: Pstate: [ 0.93  0.01 -0.07], Goal: -0.07, Action: 0.0, Dist: 0.07, Safe Value: 0.6639999747276306
# Step 58: Pstate: [ 0.98  0.   -0.07], Goal: -0.07, Action: 0.0, Dist: 0.02, Safe Value: 0.6589999794960022
# Reached the goal!
