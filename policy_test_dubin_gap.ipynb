# %%
from latent_dubins_gap import LatentDubinGap, get_args, state_to_image_pil_hq
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from colorama import Fore, Back, Style
import matplotlib.colors as mcolors

class DubinEnv():
    def __init__(self, start_state, goal_state):
        self.start_state = start_state
        self.curr_state = start_state
        self.goal_state = goal_state
        self.args = get_args()
        self.v = self.args.speed
        self.dt = self.args.dt

    def forward(self, action):
        # Apply the action to the current state
        state_obs, img_obs, state_gt, dones, acs = ([] for _ in range(5))
        pstate = self.curr_state.copy()
        pstate[0] += self.v * np.cos(self.curr_state[2]) * self.dt
        pstate[1] += self.v * np.sin(self.curr_state[2]) * self.dt
        pstate[2] += action * self.dt  # Update the heading angle
        img = state_to_image_pil_hq(pstate, self.args)

        state_obs.append(pstate[2]) # get to observe theta
        state_gt.append(pstate) # gt state
        dones.append(1)
        acs.append(action)
        img_obs.append(img)

        demo = {}
        demo['obs'] = {'image': img_obs, 'state': state_obs, 'priv_state': state_gt}
        demo['actions'] = acs
        demo['dones'] = dones
        return demo, pstate
    
    def goal_ref(self):
        # Calculate the direction towards the goal
        dx = self.goal_state[0] - self.curr_state[0]
        dy = self.goal_state[1] - self.curr_state[1]
        angle_to_goal = np.arctan2(dy, dx)
        ref_theta = angle_to_goal
        delta_theta = ref_theta - self.curr_state[2]
        # Normalize the angle to be within [-pi, pi] using modulo operation
        delta_theta = (delta_theta + np.pi) % (2 * np.pi) - np.pi
        ref_theta_dot = (delta_theta) / self.dt

        return ref_theta, np.clip(ref_theta_dot, -self.args.turnRate, self.args.turnRate)

to_np = lambda x: x.cpu().detach().numpy()

# %% [markdown]
# ## CBF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

gamma = 0.8
simlen = 100
u_min = -dubin_env.args.turnRate
u_max = dubin_env.args.turnRate
u_samples = 100
u_delta = (u_max - u_min) / u_samples
u_range = np.arange(u_min, u_max + u_delta, u_delta)  # action range for Dubins car
u_range = torch.tensor(u_range, dtype=torch.float32, device=brt.args.device).unsqueeze(-1)  # Convert to tensor

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()
    curr_safe = 1 

    Qzs = brt.evaluate_Q(to_np(feat), u_range)
    # print(f"Qzs: {Qzs}")
    cbf_cond = Qzs > gamma * Vz
    # print(f"CBF Condition: {cbf_cond}")
    Qzs_valid_idx = np.where(cbf_cond)[0]
    # print(f"u_range: {u_range.squeeze(-1).detach().cpu().numpy()}")

    if Qzs_valid_idx.size == 0:
        print(Fore.RED + "No valid actions found, using goal action."+Style.RESET_ALL)
        action = goal_act
    else:
        # Find the action that maximizes the Q-value while satisfying the CBF condition
        Qzs_valid = Qzs[Qzs_valid_idx]
        # Find the action that minimizes the distance to the goal action
        affordable_actions = torch.abs(u_range.squeeze(-1).masked_fill(torch.tensor(~cbf_cond, device=u_range.device), torch.inf) - goal_act)
        # print(f"Affordable actions: {affordable_actions}")
        closest_action = torch.argmin(affordable_actions)
        print(f"Closest action index: {closest_action}, Value: {Qzs[closest_action]}, Goal Action: {goal_act}")
        action = u_range[closest_action][0].detach().cpu().numpy()

    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action

    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    safe_values.append(safe_value)

    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])
    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 2)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot: black edge for trajectory points, red for intervention
# plot: white to red gradient for delta action magnitude
delta_action = np.abs(np.diff(np.array(actions), prepend=actions[0]))
colors = ["white", "red"]
custom_cmap = mcolors.LinearSegmentedColormap.from_list("white_red", colors)
norm = mcolors.Normalize(vmin=0, vmax=u_max - u_min)

# plot the trajectory history and circle obstacle
fig, ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)

for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)

plt.scatter(pss[:,0], pss[:,1], c=delta_action, s=10, label='Trajectory', cmap=custom_cmap, norm=norm, edgecolor='black', linewidth=0.25)
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()

# plot safe value over time
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='CBF Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 27002886 variables.
# Closest action index: 100, Value: 0.6049449443817139, Goal Action: 1.25
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.6399999856948853
# Closest action index: 100, Value: 0.6049449443817139, Goal Action: 1.25
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.6800000071525574
# Closest action index: 100, Value: 0.6649028658866882, Goal Action: 1.25
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.7099999785423279
# Closest action index: 100, Value: 0.7092595100402832, Goal Action: 1.25
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.7300000190734863
# Closest action index: 100, Value: 0.7382729649543762, Goal Action: 1.25
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.75
# Closest action index: 100, Value: 0.7446928024291992, Goal Action: 1.25
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.7599999904632568
# Closest action index: 100, Value: 0.7385079264640808, Goal Action: 1.25
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.7699999809265137
# Closest action index: 100, Value: 0.7290059328079224, Goal Action: 1.25
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.7699999809265137
# Closest action index: 100, Value: 0.7143501043319702, Goal Action: 1.25
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.7799999713897705
# Closest action index: 100, Value: 0.7088824510574341, Goal Action: 1.25
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.7799999713897705
# Closest action index: 100, Value: 0.698657751083374, Goal Action: 1.25
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.7799999713897705
# Closest action index: 100, Value: 0.6931626796722412, Goal Action: 1.25
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.7799999713897705
# Closest action index: 100, Value: 0.6828317642211914, Goal Action: 1.25
# Step 13: Pstate: [-1.07  0.66 -0.76], Goal: -0.32, Action: 1.25, Dist: 2.17, Safe Value: 0.7699999809265137
# Closest action index: 100, Value: 0.6611851453781128, Goal Action: 1.25
# Step 14: Pstate: [-1.03  0.63 -0.7 ], Goal: -0.31, Action: 1.25, Dist: 2.13, Safe Value: 0.75
# Closest action index: 100, Value: 0.622294008731842, Goal Action: 1.25
# Step 15: Pstate: [-0.99  0.6  -0.63], Goal: -0.3, Action: 1.25, Dist: 2.08, Safe Value: 0.699999988079071
# Closest action index: 100, Value: 0.5830406546592712, Goal Action: 1.25
# Step 16: Pstate: [-0.95  0.57 -0.57], Goal: -0.29, Action: 1.25, Dist: 2.03, Safe Value: 0.6499999761581421
# Closest action index: 100, Value: 0.5260894894599915, Goal Action: 1.25
# Step 17: Pstate: [-0.91  0.54 -0.51], Goal: -0.28, Action: 1.25, Dist: 1.99, Safe Value: 0.6200000047683716
# Closest action index: 80, Value: 0.49486982822418213, Goal Action: 1.25
# Step 18: Pstate: [-0.87  0.51 -0.47], Goal: -0.27, Action: 0.75, Dist: 1.94, Safe Value: 0.5799999833106995
# Closest action index: 65, Value: 0.4649677276611328, Goal Action: 1.25
# Step 19: Pstate: [-0.82  0.49 -0.45], Goal: -0.27, Action: 0.3799999952316284, Dist: 1.89, Safe Value: 0.5400000214576721
# Closest action index: 50, Value: 0.434683620929718, Goal Action: 1.25
# Step 20: Pstate: [-0.78  0.47 -0.45], Goal: -0.26, Action: -0.0, Dist: 1.84, Safe Value: 0.5
# Closest action index: 46, Value: 0.40021076798439026, Goal Action: 1.25
# Step 21: Pstate: [-0.73  0.45 -0.46], Goal: -0.26, Action: -0.10000000149011612, Dist: 1.79, Safe Value: 0.46000000834465027
# Closest action index: 48, Value: 0.3658350706100464, Goal Action: 1.25
# Step 22: Pstate: [-0.69  0.43 -0.46], Goal: -0.25, Action: -0.05000000074505806, Dist: 1.74, Safe Value: 0.4300000071525574
# Closest action index: 47, Value: 0.34551942348480225, Goal Action: 1.25
# Step 23: Pstate: [-0.64  0.4  -0.46], Goal: -0.25, Action: -0.07999999821186066, Dist: 1.69, Safe Value: 0.38999998569488525
# Closest action index: 41, Value: 0.31426674127578735, Goal Action: 1.25
# Step 24: Pstate: [-0.6   0.38 -0.47], Goal: -0.24, Action: -0.2199999988079071, Dist: 1.64, Safe Value: 0.36000001430511475
# Closest action index: 32, Value: 0.28941822052001953, Goal Action: 1.25
# Step 25: Pstate: [-0.55  0.36 -0.5 ], Goal: -0.23, Action: -0.44999998807907104, Dist: 1.6, Safe Value: 0.33000001311302185
# Closest action index: 32, Value: 0.26829662919044495, Goal Action: 1.25
# Step 26: Pstate: [-0.51  0.33 -0.52], Goal: -0.23, Action: -0.44999998807907104, Dist: 1.55, Safe Value: 0.3199999928474426
# Closest action index: 30, Value: 0.25636693835258484, Goal Action: 1.25
# Step 27: Pstate: [-0.47  0.31 -0.54], Goal: -0.22, Action: -0.5, Dist: 1.5, Safe Value: 0.3100000023841858
# Closest action index: 41, Value: 0.24910685420036316, Goal Action: 1.25
# Step 28: Pstate: [-0.42  0.28 -0.56], Goal: -0.21, Action: -0.2199999988079071, Dist: 1.45, Safe Value: 0.27000001072883606
# Closest action index: 52, Value: 0.24261197447776794, Goal Action: 1.25
# Step 29: Pstate: [-0.38  0.26 -0.55], Goal: -0.2, Action: 0.05000000074505806, Dist: 1.41, Safe Value: 0.20999999344348907
# Closest action index: 36, Value: 0.22490891814231873, Goal Action: 1.25
# Step 30: Pstate: [-0.34  0.23 -0.57], Goal: -0.18, Action: -0.3499999940395355, Dist: 1.36, Safe Value: 0.18000000715255737
# Closest action index: 28, Value: 0.20061349868774414, Goal Action: 1.25
# Step 31: Pstate: [-0.3  0.2 -0.6], Goal: -0.17, Action: -0.550000011920929, Dist: 1.31, Safe Value: 0.14000000059604645
# Closest action index: 30, Value: 0.16220729053020477, Goal Action: 1.25
# Step 32: Pstate: [-0.26  0.18 -0.62], Goal: -0.16, Action: -0.5, Dist: 1.27, Safe Value: 0.1599999964237213
# Closest action index: 28, Value: 0.14732655882835388, Goal Action: 1.25
# Step 33: Pstate: [-0.22  0.15 -0.65], Goal: -0.14, Action: -0.550000011920929, Dist: 1.22, Safe Value: 0.14000000059604645
# Closest action index: 36, Value: 0.11682165414094925, Goal Action: 1.25
# Step 34: Pstate: [-0.18  0.12 -0.67], Goal: -0.12, Action: -0.3499999940395355, Dist: 1.18, Safe Value: 0.09000000357627869
# Closest action index: 100, Value: 0.08437646180391312, Goal Action: 1.25
# Step 35: Pstate: [-0.14  0.09 -0.61], Goal: -0.1, Action: 1.25, Dist: 1.14, Safe Value: 0.10000000149011612
# Closest action index: 100, Value: 0.1010608971118927, Goal Action: 1.25
# Step 36: Pstate: [-0.09  0.06 -0.54], Goal: -0.08, Action: 1.25, Dist: 1.1, Safe Value: 0.1599999964237213
# Closest action index: 100, Value: 0.15705406665802002, Goal Action: 1.25
# Step 37: Pstate: [-0.05  0.03 -0.48], Goal: -0.05, Action: 1.25, Dist: 1.05, Safe Value: 0.20000000298023224
# Closest action index: 100, Value: 0.20498275756835938, Goal Action: 1.25
# Step 38: Pstate: [-0.01  0.01 -0.42], Goal: -0.03, Action: 1.25, Dist: 1.01, Safe Value: 0.23999999463558197
# Closest action index: 100, Value: 0.2564609944820404, Goal Action: 1.25
# Step 39: Pstate: [ 0.04 -0.01 -0.36], Goal: -0.01, Action: 1.25, Dist: 0.96, Safe Value: 0.25999999046325684
# Closest action index: 100, Value: 0.2742224335670471, Goal Action: 1.25
# Step 40: Pstate: [ 0.08 -0.03 -0.29], Goal: 0.01, Action: 1.25, Dist: 0.92, Safe Value: 0.2800000011920929
# Closest action index: 100, Value: 0.28403860330581665, Goal Action: 1.25
# Step 41: Pstate: [ 0.13 -0.04 -0.23], Goal: 0.03, Action: 1.25, Dist: 0.87, Safe Value: 0.3100000023841858
# Closest action index: 100, Value: 0.30857717990875244, Goal Action: 1.25
# Step 42: Pstate: [ 0.18 -0.06 -0.17], Goal: 0.05, Action: 1.25, Dist: 0.82, Safe Value: 0.3700000047683716
# Closest action index: 100, Value: 0.3743530809879303, Goal Action: 1.25
# Step 43: Pstate: [ 0.23 -0.06 -0.11], Goal: 0.07, Action: 1.25, Dist: 0.77, Safe Value: 0.4099999964237213
# Closest action index: 100, Value: 0.41306769847869873, Goal Action: 1.25
# Step 44: Pstate: [ 0.28 -0.07 -0.04], Goal: 0.08, Action: 1.25, Dist: 0.72, Safe Value: 0.4699999988079071
# Closest action index: 100, Value: 0.4700275659561157, Goal Action: 1.25
# Step 45: Pstate: [ 0.33 -0.07  0.02], Goal: 0.1, Action: 1.25, Dist: 0.67, Safe Value: 0.5099999904632568
# Closest action index: 100, Value: 0.509168267250061, Goal Action: 1.25
# Step 46: Pstate: [ 0.38 -0.07  0.08], Goal: 0.11, Action: 1.25, Dist: 0.62, Safe Value: 0.5699999928474426
# Closest action index: 75, Value: 0.5239731669425964, Goal Action: 0.6271125889111406
# Step 47: Pstate: [ 0.43 -0.07  0.11], Goal: 0.11, Action: 0.6200000047683716, Dist: 0.57, Safe Value: 0.6000000238418579
# Closest action index: 52, Value: 0.5374871492385864, Goal Action: 0.056747233058374036
# Step 48: Pstate: [ 0.48 -0.06  0.12], Goal: 0.12, Action: 0.05000000074505806, Dist: 0.52, Safe Value: 0.6000000238418579
# Closest action index: 50, Value: 0.5724671483039856, Goal Action: 0.012163880851092657
# Step 49: Pstate: [ 0.53 -0.05  0.12], Goal: 0.12, Action: -0.0, Dist: 0.47, Safe Value: 0.6000000238418579
# Closest action index: 51, Value: 0.5885563492774963, Goal Action: 0.013447473458638726
# Step 50: Pstate: [ 0.58 -0.05  0.12], Goal: 0.12, Action: 0.019999999552965164, Dist: 0.42, Safe Value: 0.6000000238418579
# Closest action index: 50, Value: 0.5925523638725281, Goal Action: -0.00996607290506546
# Step 51: Pstate: [ 0.63 -0.04  0.12], Goal: 0.12, Action: -0.0, Dist: 0.37, Safe Value: 0.5899999737739563
# Closest action index: 50, Value: 0.5835962891578674, Goal Action: -0.011299071031478647
# Step 52: Pstate: [ 0.68 -0.04  0.12], Goal: 0.12, Action: -0.0, Dist: 0.32, Safe Value: 0.5699999928474426
# Closest action index: 49, Value: 0.5580400824546814, Goal Action: -0.01304371478790145
# Step 53: Pstate: [ 0.73 -0.03  0.12], Goal: 0.12, Action: -0.019999999552965164, Dist: 0.27, Safe Value: 0.5400000214576721
# Closest action index: 50, Value: 0.5471075773239136, Goal Action: 0.009574496105981822
# Step 54: Pstate: [ 0.78 -0.03  0.12], Goal: 0.12, Action: -0.0, Dist: 0.22, Safe Value: 0.5299999713897705
# Closest action index: 50, Value: 0.5312429070472717, Goal Action: 0.0117133625674537
# Step 55: Pstate: [ 0.83 -0.02  0.12], Goal: 0.12, Action: -0.0, Dist: 0.17, Safe Value: 0.5099999904632568
# Closest action index: 51, Value: 0.5115063786506653, Goal Action: 0.015082723039920864
# Step 56: Pstate: [ 0.88 -0.01  0.12], Goal: 0.12, Action: 0.019999999552965164, Dist: 0.12, Safe Value: 0.4699999988079071
# Closest action index: 50, Value: 0.4938738942146301, Goal Action: -0.0038267800188762635
# Step 57: Pstate: [ 0.93 -0.01  0.12], Goal: 0.12, Action: -0.0, Dist: 0.07, Safe Value: 0.4300000071525574
# Closest action index: 50, Value: 0.4618321657180786, Goal Action: -0.006418685146085679
# Step 58: Pstate: [ 0.98 -0.    0.12], Goal: 0.12, Action: -0.0, Dist: 0.02, Safe Value: 0.4099999964237213
# Reached the goal!

# %% [markdown]
# ## LRSF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.5
simlen = 100

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()    
    curr_safe = 1 

    if safe_value < epsilon: 
        safe_action = brt.find_a(feat.detach().cpu().numpy())
        action = safe_action[0]
        curr_safe = 0 # when safe action is engaged
        print(Fore.RED + 'Safe action engaged!' + Style.RESET_ALL)
    else:
        action = goal_act # nominal action otherwise
    
    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    
    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action
    
    safe_values.append(safe_value)
    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])

    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 3)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot: black edge for trajectory points, red for intervention
# plot: white to red gradient for delta action magnitude
delta_action = np.abs(np.diff(np.array(actions), prepend=actions[0]))
colors = ["white", "red"]
custom_cmap = mcolors.LinearSegmentedColormap.from_list("white_red", colors)
norm = mcolors.Normalize(vmin=0, vmax=u_max - u_min)

# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)
safe_action_idx = np.where(np.array(current_safe) == 1)
unsafe_action_idx = np.where(np.array(current_safe) == 0)
plt.scatter(pss[safe_action_idx][:,0], pss[safe_action_idx][:,1], c=delta_action[safe_action_idx], s=10, label='Trajectory', cmap=custom_cmap, norm=norm, linewidths=0.25, edgecolor='black')
plt.scatter(pss[unsafe_action_idx][:,0], pss[unsafe_action_idx][:,1], c=delta_action[unsafe_action_idx], s=10, label='Trajectory', cmap=custom_cmap, norm=norm, linewidths=0.25, edgecolor='red')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()
    
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='Safety Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 27002886 variables.
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.640999972820282
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.6779999732971191
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.7049999833106995
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.734000027179718
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.7519999742507935
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.7639999985694885
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.7680000066757202
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.7720000147819519
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.7770000100135803
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.7789999842643738
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.7789999842643738
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.7770000100135803
# Step 13: Pstate: [-1.07  0.66 -0.76], Goal: -0.32, Action: 1.25, Dist: 2.17, Safe Value: 0.7749999761581421
# Step 14: Pstate: [-1.03  0.63 -0.7 ], Goal: -0.31, Action: 1.25, Dist: 2.13, Safe Value: 0.7480000257492065
# Step 15: Pstate: [-0.99  0.6  -0.63], Goal: -0.3, Action: 1.25, Dist: 2.08, Safe Value: 0.7009999752044678
# Step 16: Pstate: [-0.95  0.57 -0.57], Goal: -0.29, Action: 1.25, Dist: 2.03, Safe Value: 0.6549999713897705
# Step 17: Pstate: [-0.91  0.54 -0.51], Goal: -0.28, Action: 1.25, Dist: 1.99, Safe Value: 0.6159999966621399
# Step 18: Pstate: [-0.87  0.51 -0.45], Goal: -0.27, Action: 1.25, Dist: 1.94, Safe Value: 0.578000009059906
# Step 19: Pstate: [-0.82  0.49 -0.38], Goal: -0.27, Action: 1.25, Dist: 1.89, Safe Value: 0.5410000085830688
# Step 20: Pstate: [-0.78  0.47 -0.32], Goal: -0.26, Action: 1.25, Dist: 1.84, Safe Value: 0.492000013589859
# Safe action engaged!
# Step 21: Pstate: [-0.73  0.46 -0.38], Goal: -0.26, Action: -1.25, Dist: 1.79, Safe Value: 0.4090000092983246
# Safe action engaged!
# Step 22: Pstate: [-0.68  0.44 -0.45], Goal: -0.26, Action: -1.25, Dist: 1.74, Safe Value: 0.39100000262260437
# Safe action engaged!
# Step 23: Pstate: [-0.64  0.42 -0.51], Goal: -0.26, Action: -1.25, Dist: 1.69, Safe Value: 0.3709999918937683
# Safe action engaged!
# Step 24: Pstate: [-0.59  0.39 -0.57], Goal: -0.25, Action: -1.25, Dist: 1.64, Safe Value: 0.3580000102519989
# Safe action engaged!
# Step 25: Pstate: [-0.55  0.37 -0.63], Goal: -0.24, Action: -1.25, Dist: 1.59, Safe Value: 0.35499998927116394
# Safe action engaged!
# Step 26: Pstate: [-0.51  0.34 -0.7 ], Goal: -0.23, Action: -1.25, Dist: 1.55, Safe Value: 0.33799999952316284
# Safe action engaged!
# Step 27: Pstate: [-0.47  0.3  -0.76], Goal: -0.22, Action: -1.25, Dist: 1.5, Safe Value: 0.30799999833106995
# Safe action engaged!
# Step 28: Pstate: [-0.44  0.27 -0.82], Goal: -0.2, Action: -1.25, Dist: 1.46, Safe Value: 0.26600000262260437
# Safe action engaged!
# Step 29: Pstate: [-0.4   0.23 -0.88], Goal: -0.19, Action: -1.2300000190734863, Dist: 1.42, Safe Value: 0.1809999942779541
# Safe action engaged!
# Step 30: Pstate: [-0.37  0.2  -0.82], Goal: -0.17, Action: 1.2300000190734863, Dist: 1.38, Safe Value: 0.1289999932050705
# Safe action engaged!
# Step 31: Pstate: [-0.34  0.16 -0.76], Goal: -0.14, Action: 1.25, Dist: 1.35, Safe Value: 0.1589999943971634
# Safe action engaged!
# Step 32: Pstate: [-0.3   0.12 -0.7 ], Goal: -0.12, Action: 1.25, Dist: 1.31, Safe Value: 0.1809999942779541
# Safe action engaged!
# Step 33: Pstate: [-0.26  0.09 -0.63], Goal: -0.1, Action: 1.25, Dist: 1.27, Safe Value: 0.17299999296665192
# Safe action engaged!
# Step 34: Pstate: [-0.22  0.06 -0.57], Goal: -0.07, Action: 1.25, Dist: 1.22, Safe Value: 0.15800000727176666
# Safe action engaged!
# Step 35: Pstate: [-0.18  0.04 -0.51], Goal: -0.05, Action: 1.25, Dist: 1.18, Safe Value: 0.16200000047683716
# Safe action engaged!
# Step 36: Pstate: [-0.14  0.01 -0.45], Goal: -0.03, Action: 1.25, Dist: 1.14, Safe Value: 0.18299999833106995
# Safe action engaged!
# Step 37: Pstate: [-0.09 -0.01 -0.38], Goal: -0.01, Action: 1.25, Dist: 1.09, Safe Value: 0.19200000166893005
# Safe action engaged!
# Step 38: Pstate: [-0.04 -0.03 -0.32], Goal: 0.01, Action: 1.25, Dist: 1.04, Safe Value: 0.21400000154972076
# Safe action engaged!
# Step 39: Pstate: [ 0.   -0.04 -0.26], Goal: 0.03, Action: 1.25, Dist: 1.0, Safe Value: 0.2329999953508377
# Safe action engaged!
# Step 40: Pstate: [ 0.05 -0.06 -0.2 ], Goal: 0.04, Action: 1.25, Dist: 0.95, Safe Value: 0.23800000548362732
# Safe action engaged!
# Step 41: Pstate: [ 0.1  -0.07 -0.13], Goal: 0.06, Action: 1.25, Dist: 0.9, Safe Value: 0.25600001215934753
# Safe action engaged!
# Step 42: Pstate: [ 0.15 -0.07 -0.07], Goal: 0.07, Action: 1.25, Dist: 0.85, Safe Value: 0.2759999930858612
# Safe action engaged!
# Step 43: Pstate: [ 0.2  -0.08 -0.01], Goal: 0.09, Action: 1.25, Dist: 0.8, Safe Value: 0.32899999618530273
# Safe action engaged!
# Step 44: Pstate: [ 0.25 -0.08  0.05], Goal: 0.1, Action: 1.25, Dist: 0.75, Safe Value: 0.3959999978542328
# Safe action engaged!
# Step 45: Pstate: [ 0.3  -0.07  0.12], Goal: 0.1, Action: 1.25, Dist: 0.7, Safe Value: 0.4580000042915344
# Safe action engaged!
# Step 46: Pstate: [ 0.35 -0.07  0.18], Goal: 0.11, Action: 1.25, Dist: 0.65, Safe Value: 0.5479999780654907
# Step 47: Pstate: [ 0.4  -0.06  0.12], Goal: 0.11, Action: -1.25, Dist: 0.6, Safe Value: 0.5699999928474426
# Step 48: Pstate: [ 0.45 -0.05  0.1 ], Goal: 0.1, Action: -0.34, Dist: 0.55, Safe Value: 0.597000002861023
# Step 49: Pstate: [ 0.5  -0.05  0.1 ], Goal: 0.1, Action: -0.03, Dist: 0.5, Safe Value: 0.6010000109672546
# Step 50: Pstate: [ 0.55 -0.04  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.45, Safe Value: 0.6029999852180481
# Step 51: Pstate: [ 0.6  -0.04  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.4, Safe Value: 0.597000002861023
# Step 52: Pstate: [ 0.65 -0.03  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.35, Safe Value: 0.5830000042915344
# Step 53: Pstate: [ 0.7  -0.03  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.3, Safe Value: 0.5550000071525574
# Step 54: Pstate: [ 0.75 -0.02  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.25, Safe Value: 0.5389999747276306
# Step 55: Pstate: [ 0.8  -0.02  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.2, Safe Value: 0.5220000147819519
# Step 56: Pstate: [ 0.85 -0.02  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.15, Safe Value: 0.5009999871253967
# Step 57: Pstate: [ 0.9  -0.01  0.1 ], Goal: 0.1, Action: -0.0, Dist: 0.1, Safe Value: 0.4569999873638153
# Safe action engaged!
# Step 58: Pstate: [ 0.95 -0.01  0.16], Goal: 0.1, Action: 1.25, Dist: 0.05, Safe Value: 0.414000004529953
# Safe action engaged!
# Step 59: Pstate: [1.   0.   0.22], Goal: 0.1, Action: 1.2200000286102295, Dist: 0.01, Safe Value: 0.38999998569488525
# Reached the goal!
