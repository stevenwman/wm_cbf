# %%
from latent_dubins_ca_wm_pil import LatentDubinContinuousAction, get_args, state_to_image_pil_hq
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches

class DubinEnv():
    def __init__(self, start_state, goal_state):
        self.start_state = start_state
        self.curr_state = start_state
        self.goal_state = goal_state
        self.args = get_args()
        self.v = self.args.speed
        self.dt = self.args.dt

    def forward(self, action):
        # Apply the action to the current state
        state_obs, img_obs, state_gt, dones, acs = ([] for _ in range(5))
        pstate = self.curr_state.copy()
        pstate[0] += self.v * np.cos(self.curr_state[2]) * self.dt
        pstate[1] += self.v * np.sin(self.curr_state[2]) * self.dt
        pstate[2] += action * self.dt  # Update the heading angle
        img = state_to_image_pil_hq(pstate, self.args)

        state_obs.append(pstate[2]) # get to observe theta
        state_gt.append(pstate) # gt state
        dones.append(1)
        acs.append(action)
        img_obs.append(img)

        demo = {}
        demo['obs'] = {'image': img_obs, 'state': state_obs, 'priv_state': state_gt}
        demo['actions'] = acs
        demo['dones'] = dones
        return demo, pstate
    
    def goal_ref(self):
        # Calculate the direction towards the goal
        dx = self.goal_state[0] - self.curr_state[0]
        dy = self.goal_state[1] - self.curr_state[1]
        angle_to_goal = np.arctan2(dy, dx)
        ref_theta = angle_to_goal
        delta_theta = ref_theta - self.curr_state[2]
        # Normalize the angle to be within [-pi, pi] using modulo operation
        delta_theta = (delta_theta + np.pi) % (2 * np.pi) - np.pi
        ref_theta_dot = (delta_theta) / self.dt

        return ref_theta, np.clip(ref_theta_dot, -self.args.turnRate, self.args.turnRate)
# Out:
# /home/clown2/Desktop/Work/Research/wm_cbf

# %% [markdown]
# ## CBF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.0, 1.0, 0.0]),
                     goal_state=0.6*np.array([1, -1, 0.0]))

brt = LatentDubinContinuousAction()

priv_states = []
actions = []
goal_actions = []
current_safe = []

epsilon = 0.2
gamma = 0.925
simlen = 100
u_min = -dubin_env.args.turnRate
u_max = dubin_env.args.turnRate
u_samples = 100
u_delta = (u_max - u_min) / u_samples
u_range = np.arange(u_min, u_max + u_delta, u_delta)  # action range for Dubins car
u_range = torch.tensor(u_range, dtype=torch.float32, device=brt.args.device).unsqueeze(-1)  # Convert to tensor

to_np = lambda x: x.cpu().detach().numpy()
# first step
demo, priv_state = dubin_env.forward(0)
feat = brt.data_to_feat(demo)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
Vz = np.min([Vz, to_np(Lz)])

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()
    curr_safe = 1 

    Qzs = brt.evaluate_Q(to_np(feat), u_range)
    # print(f"Qzs: {Qzs}")
    cbf_cond = Qzs > gamma * Vz
    # print(f"CBF Condition: {cbf_cond}")
    Qzs_valid_idx = np.where(cbf_cond)[0]
    # print(f"u_range: {u_range.squeeze(-1).detach().cpu().numpy()}")

    if Qzs_valid_idx.size == 0:
        print("No valid actions found, using goal action.")
        action = goal_act
    else:
        # Find the action that maximizes the Q-value while satisfying the CBF condition
        Qzs_valid = Qzs[Qzs_valid_idx]
        # Find the action that minimizes the distance to the goal action
        affordable_actions = torch.abs(u_range.squeeze(-1).masked_fill(torch.tensor(~cbf_cond, device=u_range.device), torch.inf) - goal_act)
        # print(f"Affordable actions: {affordable_actions}")
        closest_action = torch.argmin(affordable_actions)
        print(f"Closest action index: {closest_action}, Value: {Qzs[closest_action]}, Goal Action: {goal_act}")
        action = u_range[closest_action][0].detach().cpu().numpy()

    demo, priv_state = dubin_env.forward(action)
    feat = brt.data_to_feat(demo)
    Vz = brt.evaluate_V(to_np(feat))[0]
    Lz = brt.margin_fn(feat)[0][0][0]
    Vz = np.min([Vz, to_np(Lz)])
    safe_value = Vz = np.min([Vz, to_np(Lz)])
    dubin_env.curr_state = priv_state  # Update the current state in the environment

    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)

    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])
    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 2)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break


# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
circle = patches.Circle((0,0), 0.5, edgecolor=(1,0,0), facecolor='none')
ax.add_patch(circle)
col = np.where(np.array(current_safe) == 1, 'blue', 'red')
plt.scatter(pss[:,0], pss[:,1], c=col, s=10, label='Trajectory')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 27002886 variables.
# Closest action index: 0, Value: 0.5459182858467102, Goal Action: -1.25
# Step 1: Pstate: [-0.95  1.   -0.06], Goal: -0.79, Action: -1.25, Dist: 2.23, Safe Value: 0.5600000023841858
# Closest action index: 0, Value: 0.5558602809906006, Goal Action: -1.25
# Step 2: Pstate: [-0.9   1.   -0.12], Goal: -0.8, Action: -1.25, Dist: 2.19, Safe Value: 0.5799999833106995
# Closest action index: 0, Value: 0.5890130996704102, Goal Action: -1.25
# Step 3: Pstate: [-0.85  0.99 -0.19], Goal: -0.82, Action: -1.25, Dist: 2.15, Safe Value: 0.5799999833106995
# Closest action index: 0, Value: 0.6013495922088623, Goal Action: -1.25
# Step 4: Pstate: [-0.8   0.98 -0.25], Goal: -0.83, Action: -1.25, Dist: 2.11, Safe Value: 0.6000000238418579
# Closest action index: 1, Value: 0.5600674152374268, Goal Action: -1.25
# Step 5: Pstate: [-0.75  0.97 -0.31], Goal: -0.85, Action: -1.2200000286102295, Dist: 2.07, Safe Value: 0.6299999952316284
# Closest action index: 36, Value: 0.5784984230995178, Goal Action: -1.25
# Step 6: Pstate: [-0.71  0.95 -0.33], Goal: -0.86, Action: -0.3499999940395355, Dist: 2.03, Safe Value: 0.6399999856948853
# Closest action index: 54, Value: 0.5899730920791626, Goal Action: -1.25
# Step 7: Pstate: [-0.66  0.94 -0.32], Goal: -0.87, Action: 0.10000000149011612, Dist: 1.99, Safe Value: 0.6399999856948853
# Closest action index: 64, Value: 0.5877245664596558, Goal Action: -1.25
# Step 8: Pstate: [-0.61  0.92 -0.31], Goal: -0.89, Action: 0.3499999940395355, Dist: 1.94, Safe Value: 0.6200000047683716
# Closest action index: 66, Value: 0.5755389928817749, Goal Action: -1.25
# Step 9: Pstate: [-0.56  0.91 -0.29], Goal: -0.9, Action: 0.4000000059604645, Dist: 1.9, Safe Value: 0.6000000238418579
# Closest action index: 63, Value: 0.5601117610931396, Goal Action: -1.25
# Step 10: Pstate: [-0.51  0.89 -0.27], Goal: -0.91, Action: 0.3199999928474426, Dist: 1.86, Safe Value: 0.6000000238418579
# Closest action index: 62, Value: 0.5515707731246948, Goal Action: -1.25
# Step 11: Pstate: [-0.47  0.88 -0.26], Goal: -0.93, Action: 0.30000001192092896, Dist: 1.82, Safe Value: 0.5899999737739563
# Closest action index: 61, Value: 0.5457960367202759, Goal Action: -1.25
# Step 12: Pstate: [-0.42  0.87 -0.24], Goal: -0.95, Action: 0.2800000011920929, Dist: 1.79, Safe Value: 0.5899999737739563
# Closest action index: 67, Value: 0.5416355133056641, Goal Action: -1.25
# Step 13: Pstate: [-0.37  0.85 -0.22], Goal: -0.96, Action: 0.41999998688697815, Dist: 1.75, Safe Value: 0.5799999833106995
# Closest action index: 70, Value: 0.5370107889175415, Goal Action: -1.25
# Step 14: Pstate: [-0.32  0.84 -0.19], Goal: -0.98, Action: 0.5, Dist: 1.71, Safe Value: 0.5699999928474426
# Closest action index: 67, Value: 0.5303296446800232, Goal Action: -1.25
# Step 15: Pstate: [-0.27  0.83 -0.17], Goal: -1.0, Action: 0.41999998688697815, Dist: 1.68, Safe Value: 0.5699999928474426
# Closest action index: 49, Value: 0.5237613916397095, Goal Action: -1.25
# Step 16: Pstate: [-0.22  0.83 -0.17], Goal: -1.02, Action: -0.019999999552965164, Dist: 1.65, Safe Value: 0.5600000023841858
# Closest action index: 21, Value: 0.5174658298492432, Goal Action: -1.25
# Step 17: Pstate: [-0.17  0.82 -0.21], Goal: -1.05, Action: -0.7200000286102295, Dist: 1.61, Safe Value: 0.550000011920929
# Closest action index: 12, Value: 0.5065211057662964, Goal Action: -1.25
# Step 18: Pstate: [-0.12  0.81 -0.26], Goal: -1.07, Action: -0.949999988079071, Dist: 1.58, Safe Value: 0.5099999904632568
# Closest action index: 0, Value: 0.47804903984069824, Goal Action: -1.25
# Step 19: Pstate: [-0.08  0.79 -0.32], Goal: -1.09, Action: -1.25, Dist: 1.55, Safe Value: 0.46000000834465027
# Closest action index: 0, Value: 0.4475955665111542, Goal Action: -1.25
# Step 20: Pstate: [-0.03  0.78 -0.38], Goal: -1.12, Action: -1.25, Dist: 1.51, Safe Value: 0.4399999976158142
# Closest action index: 12, Value: 0.40844500064849854, Goal Action: -1.25
# Step 21: Pstate: [ 0.02  0.76 -0.43], Goal: -1.14, Action: -0.949999988079071, Dist: 1.48, Safe Value: 0.41999998688697815
# Closest action index: 31, Value: 0.38808146119117737, Goal Action: -1.25
# Step 22: Pstate: [ 0.06  0.74 -0.45], Goal: -1.17, Action: -0.47999998927116394, Dist: 1.44, Safe Value: 0.4000000059604645
# Closest action index: 33, Value: 0.37006664276123047, Goal Action: -1.25
# Step 23: Pstate: [ 0.11  0.72 -0.48], Goal: -1.19, Action: -0.41999998688697815, Dist: 1.4, Safe Value: 0.38999998569488525
# Closest action index: 0, Value: 0.36870378255844116, Goal Action: -1.25
# Step 24: Pstate: [ 0.15  0.69 -0.54], Goal: -1.21, Action: -1.25, Dist: 1.37, Safe Value: 0.33000001311302185
# Closest action index: 0, Value: 0.33620184659957886, Goal Action: -1.25
# Step 25: Pstate: [ 0.2   0.67 -0.6 ], Goal: -1.24, Action: -1.25, Dist: 1.33, Safe Value: 0.30000001192092896
# Closest action index: 0, Value: 0.3005381226539612, Goal Action: -1.25
# Step 26: Pstate: [ 0.24  0.64 -0.66], Goal: -1.26, Action: -1.25, Dist: 1.29, Safe Value: 0.30000001192092896
# Closest action index: 43, Value: 0.27840399742126465, Goal Action: -1.25
# Step 27: Pstate: [ 0.28  0.61 -0.67], Goal: -1.29, Action: -0.18000000715255737, Dist: 1.25, Safe Value: 0.30000001192092896
# Closest action index: 56, Value: 0.2762068212032318, Goal Action: -1.25
# Step 28: Pstate: [ 0.31  0.58 -0.66], Goal: -1.31, Action: 0.15000000596046448, Dist: 1.21, Safe Value: 0.2800000011920929
# Closest action index: 0, Value: 0.2720603942871094, Goal Action: -1.25
# Step 29: Pstate: [ 0.35  0.55 -0.73], Goal: -1.33, Action: -1.25, Dist: 1.17, Safe Value: 0.25999999046325684
# Closest action index: 0, Value: 0.27407899498939514, Goal Action: -1.25
# Step 30: Pstate: [ 0.39  0.51 -0.79], Goal: -1.36, Action: -1.25, Dist: 1.13, Safe Value: 0.23000000417232513
# Closest action index: 0, Value: 0.24783074855804443, Goal Action: -1.25
# Step 31: Pstate: [ 0.43  0.48 -0.85], Goal: -1.39, Action: -1.25, Dist: 1.09, Safe Value: 0.20999999344348907
# Closest action index: 0, Value: 0.22369055449962616, Goal Action: -1.25
# Step 32: Pstate: [ 0.46  0.44 -0.91], Goal: -1.41, Action: -1.25, Dist: 1.05, Safe Value: 0.20999999344348907
# Closest action index: 0, Value: 0.2253059595823288, Goal Action: -1.25
# Step 33: Pstate: [ 0.49  0.4  -0.98], Goal: -1.44, Action: -1.25, Dist: 1.01, Safe Value: 0.20000000298023224
# Closest action index: 0, Value: 0.24084904789924622, Goal Action: -1.25
# Step 34: Pstate: [ 0.52  0.36 -1.04], Goal: -1.46, Action: -1.25, Dist: 0.96, Safe Value: 0.20999999344348907
# Closest action index: 0, Value: 0.2828001081943512, Goal Action: -1.25
# Step 35: Pstate: [ 0.54  0.32 -1.1 ], Goal: -1.49, Action: -1.25, Dist: 0.92, Safe Value: 0.20000000298023224
# Closest action index: 0, Value: 0.30020034313201904, Goal Action: -1.25
# Step 36: Pstate: [ 0.57  0.27 -1.16], Goal: -1.51, Action: -1.25, Dist: 0.87, Safe Value: 0.20999999344348907
# Closest action index: 0, Value: 0.31861749291419983, Goal Action: -1.25
# Step 37: Pstate: [ 0.59  0.23 -1.23], Goal: -1.53, Action: -1.25, Dist: 0.83, Safe Value: 0.20000000298023224
# Closest action index: 0, Value: 0.32235318422317505, Goal Action: -1.25
# Step 38: Pstate: [ 0.6   0.18 -1.29], Goal: -1.55, Action: -1.25, Dist: 0.78, Safe Value: 0.2199999988079071
# Closest action index: 0, Value: 0.3288843631744385, Goal Action: -1.25
# Step 39: Pstate: [ 0.62  0.13 -1.35], Goal: -1.57, Action: -1.25, Dist: 0.73, Safe Value: 0.25
# Closest action index: 0, Value: 0.3560679256916046, Goal Action: -1.25
# Step 40: Pstate: [ 0.63  0.08 -1.41], Goal: -1.59, Action: -1.25, Dist: 0.68, Safe Value: 0.25999999046325684
# Closest action index: 0, Value: 0.3898722529411316, Goal Action: -1.25
# Step 41: Pstate: [ 0.64  0.03 -1.48], Goal: -1.61, Action: -1.25, Dist: 0.63, Safe Value: 0.2800000011920929
# Closest action index: 0, Value: 0.4155556559562683, Goal Action: -1.25
# Step 42: Pstate: [ 0.64 -0.02 -1.54], Goal: -1.63, Action: -1.25, Dist: 0.58, Safe Value: 0.3199999928474426
# Closest action index: 0, Value: 0.43529218435287476, Goal Action: -1.25
# Step 43: Pstate: [ 0.64 -0.07 -1.6 ], Goal: -1.64, Action: -1.25, Dist: 0.53, Safe Value: 0.33000001311302185
# Closest action index: 13, Value: 0.4326537549495697, Goal Action: -0.9140943229965259
# Step 44: Pstate: [ 0.64 -0.12 -1.65], Goal: -1.65, Action: -0.9200000166893005, Dist: 0.48, Safe Value: 0.3700000047683716
# Closest action index: 47, Value: 0.45156329870224, Goal Action: -0.08356646103591103
# Step 45: Pstate: [ 0.64 -0.17 -1.65], Goal: -1.65, Action: -0.07999999821186066, Dist: 0.43, Safe Value: 0.4000000059604645
# Closest action index: 49, Value: 0.43975964188575745, Goal Action: -0.01820224567689266
# Step 46: Pstate: [ 0.63 -0.22 -1.65], Goal: -1.65, Action: -0.019999999552965164, Dist: 0.38, Safe Value: 0.4300000071525574
# Closest action index: 50, Value: 0.42826980352401733, Goal Action: 0.00442534957389995
# Step 47: Pstate: [ 0.63 -0.27 -1.65], Goal: -1.65, Action: -0.0, Dist: 0.33, Safe Value: 0.4699999988079071
# Closest action index: 50, Value: 0.4452327787876129, Goal Action: 0.005088573152711717
# Step 48: Pstate: [ 0.62 -0.32 -1.65], Goal: -1.65, Action: -0.0, Dist: 0.28, Safe Value: 0.47999998927116394
# Closest action index: 52, Value: 0.44714629650115967, Goal Action: 0.005985635525274091
# Step 49: Pstate: [ 0.62 -0.37 -1.65], Goal: -1.65, Action: 0.05000000074505806, Dist: 0.23, Safe Value: 0.5
# Closest action index: 58, Value: 0.46573448181152344, Goal Action: -0.042733326325583576
# Step 50: Pstate: [ 0.62 -0.42 -1.64], Goal: -1.65, Action: 0.20000000298023224, Dist: 0.18, Safe Value: 0.5199999809265137
# Closest action index: 51, Value: 0.48340389132499695, Goal Action: -0.25436939006299397
# Step 51: Pstate: [ 0.61 -0.47 -1.64], Goal: -1.65, Action: 0.019999999552965164, Dist: 0.13, Safe Value: 0.5299999713897705
# Closest action index: 42, Value: 0.48763173818588257, Goal Action: -0.3745439590103583
# Step 52: Pstate: [ 0.61 -0.52 -1.65], Goal: -1.66, Action: -0.20000000298023224, Dist: 0.08, Safe Value: 0.5199999809265137
# Closest action index: 53, Value: 0.4774850010871887, Goal Action: -0.39842731455848934
# Step 53: Pstate: [ 0.6  -0.57 -1.65], Goal: -1.67, Action: 0.07999999821186066, Dist: 0.03, Safe Value: 0.5
# Reached the goal!

# %% [markdown]
# ## LRSF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.0, 1.0, 0.0]),
                     goal_state=0.6*np.array([1, -1, 0.0]))

brt = LatentDubinContinuousAction()

priv_states = []
actions = []
goal_actions = []
current_safe = []

epsilon = 0.25
simlen = 1000

# first step
demo, priv_state = dubin_env.forward(0)
feat = brt.data_to_feat(demo)
safe_value = Vz = brt.evaluate_V(to_np(feat))[0]

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()    
    curr_safe = 1 

    if safe_value < epsilon: 
        safe_action = brt.find_a(feat.detach().cpu().numpy())
        action = safe_action[0]
        curr_safe = 0 # when safe action is engaged
        print('Safe action engaged!')
    else:
        action = goal_act # nominal action otherwise
    
    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    
    demo, priv_state = dubin_env.forward(action)
    feat = brt.data_to_feat(demo, action=action)
    safe_value = Vz = brt.evaluate_V(to_np(feat))[0]
    dubin_env.curr_state = priv_state  # Update the current state in the environment
    
    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])
    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 3)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break


# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
circle = patches.Circle((0,0), 0.5, edgecolor=(1,0,0), facecolor='none')
ax.add_patch(circle)
col = np.where(np.array(current_safe) == 1, 'blue', 'red')
plt.scatter(pss[:,0], pss[:,1], c=col, s=10, label='Trajectory')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()
# Out:
# /home/clown2/anaconda3/envs/wm_cbf/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# /home/clown2/Desktop/Work/Research/wm_cbf/PytorchReachability/dreamerv3-torch/tools.py:889: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self._scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# Optimizer model_opt has 27002886 variables.
# Step 1: Pstate: [-0.95  1.   -0.06], Goal: -0.79, Action: -1.25, Dist: 2.23, Safe Value: 0.5550000071525574
# Step 2: Pstate: [-0.9   1.   -0.12], Goal: -0.8, Action: -1.25, Dist: 2.19, Safe Value: 0.5770000219345093
# Step 3: Pstate: [-0.85  0.99 -0.19], Goal: -0.82, Action: -1.25, Dist: 2.15, Safe Value: 0.5809999704360962
# Step 4: Pstate: [-0.8   0.98 -0.25], Goal: -0.83, Action: -1.25, Dist: 2.11, Safe Value: 0.6050000190734863
# Step 5: Pstate: [-0.75  0.97 -0.31], Goal: -0.85, Action: -1.25, Dist: 2.07, Safe Value: 0.625
# Step 6: Pstate: [-0.71  0.95 -0.38], Goal: -0.86, Action: -1.25, Dist: 2.03, Safe Value: 0.6240000128746033
# Step 7: Pstate: [-0.66  0.94 -0.44], Goal: -0.87, Action: -1.25, Dist: 1.99, Safe Value: 0.5799999833106995
# Step 8: Pstate: [-0.61  0.91 -0.5 ], Goal: -0.88, Action: -1.25, Dist: 1.94, Safe Value: 0.4909999966621399
# Step 9: Pstate: [-0.57  0.89 -0.56], Goal: -0.9, Action: -1.25, Dist: 1.89, Safe Value: 0.30300000309944153
# Step 10: Pstate: [-0.53  0.86 -0.62], Goal: -0.91, Action: -1.25, Dist: 1.85, Safe Value: 0.12399999797344208
# Safe action engaged!
# Step 11: Pstate: [-0.49  0.83 -0.56], Goal: -0.91, Action: 1.25, Dist: 1.8, Safe Value: 0.19699999690055847
# Safe action engaged!
# Step 12: Pstate: [-0.44  0.81 -0.5 ], Goal: -0.92, Action: 1.25, Dist: 1.75, Safe Value: 0.27799999713897705
# Step 13: Pstate: [-0.4   0.78 -0.56], Goal: -0.93, Action: -1.25, Dist: 1.71, Safe Value: 0.08799999952316284
# Safe action engaged!
# Step 14: Pstate: [-0.36  0.76 -0.5 ], Goal: -0.94, Action: 1.25, Dist: 1.66, Safe Value: 0.17499999701976776
# Safe action engaged!
# Step 15: Pstate: [-0.31  0.73 -0.44], Goal: -0.96, Action: 1.25, Dist: 1.62, Safe Value: 0.2150000035762787
# Safe action engaged!
# Step 16: Pstate: [-0.27  0.71 -0.38], Goal: -0.97, Action: 1.25, Dist: 1.57, Safe Value: 0.23199999332427979
# Safe action engaged!
# Step 17: Pstate: [-0.22  0.69 -0.31], Goal: -0.99, Action: 1.25, Dist: 1.53, Safe Value: 0.24699999392032623
# Safe action engaged!
# Step 18: Pstate: [-0.18  0.68 -0.25], Goal: -1.0, Action: 1.25, Dist: 1.49, Safe Value: 0.23899999260902405
# Safe action engaged!
# Step 19: Pstate: [-0.13  0.67 -0.19], Goal: -1.03, Action: 1.25, Dist: 1.46, Safe Value: 0.24500000476837158
# Safe action engaged!
# Step 20: Pstate: [-0.08  0.66 -0.12], Goal: -1.05, Action: 1.25, Dist: 1.43, Safe Value: 0.28600001335144043
# Step 21: Pstate: [-0.03  0.65 -0.19], Goal: -1.08, Action: -1.25, Dist: 1.4, Safe Value: 0.2329999953508377
# Safe action engaged!
# Step 22: Pstate: [ 0.02  0.64 -0.12], Goal: -1.11, Action: 1.25, Dist: 1.37, Safe Value: 0.3070000112056732
# Step 23: Pstate: [ 0.07  0.63 -0.19], Goal: -1.13, Action: -1.25, Dist: 1.34, Safe Value: 0.3199999928474426
# Step 24: Pstate: [ 0.12  0.63 -0.25], Goal: -1.17, Action: -1.25, Dist: 1.32, Safe Value: 0.29899999499320984
# Step 25: Pstate: [ 0.17  0.61 -0.31], Goal: -1.2, Action: -1.25, Dist: 1.29, Safe Value: 0.2639999985694885
# Step 26: Pstate: [ 0.22  0.6  -0.38], Goal: -1.23, Action: -1.25, Dist: 1.26, Safe Value: 0.25200000405311584
# Step 27: Pstate: [ 0.26  0.58 -0.44], Goal: -1.26, Action: -1.25, Dist: 1.23, Safe Value: 0.2680000066757202
# Step 28: Pstate: [ 0.31  0.56 -0.5 ], Goal: -1.29, Action: -1.25, Dist: 1.19, Safe Value: 0.2980000078678131
# Step 29: Pstate: [ 0.35  0.53 -0.56], Goal: -1.32, Action: -1.25, Dist: 1.16, Safe Value: 0.335999995470047
# Step 30: Pstate: [ 0.39  0.51 -0.62], Goal: -1.36, Action: -1.25, Dist: 1.13, Safe Value: 0.3479999899864197
# Step 31: Pstate: [ 0.43  0.48 -0.69], Goal: -1.39, Action: -1.25, Dist: 1.09, Safe Value: 0.35199999809265137
# Step 32: Pstate: [ 0.47  0.45 -0.75], Goal: -1.42, Action: -1.25, Dist: 1.05, Safe Value: 0.3499999940395355
# Step 33: Pstate: [ 0.51  0.41 -0.81], Goal: -1.45, Action: -1.25, Dist: 1.02, Safe Value: 0.36399999260902405
# Step 34: Pstate: [ 0.54  0.38 -0.88], Goal: -1.48, Action: -1.25, Dist: 0.98, Safe Value: 0.3720000088214874
# Step 35: Pstate: [ 0.58  0.34 -0.94], Goal: -1.51, Action: -1.25, Dist: 0.94, Safe Value: 0.41100001335144043
# Step 36: Pstate: [ 0.61  0.3  -1.  ], Goal: -1.55, Action: -1.25, Dist: 0.9, Safe Value: 0.46299999952316284
# Step 37: Pstate: [ 0.63  0.26 -1.06], Goal: -1.58, Action: -1.25, Dist: 0.86, Safe Value: 0.4860000014305115
# Step 38: Pstate: [ 0.66  0.21 -1.12], Goal: -1.61, Action: -1.25, Dist: 0.81, Safe Value: 0.5090000033378601
# Step 39: Pstate: [ 0.68  0.17 -1.19], Goal: -1.64, Action: -1.25, Dist: 0.77, Safe Value: 0.5220000147819519
# Step 40: Pstate: [ 0.7   0.12 -1.25], Goal: -1.67, Action: -1.25, Dist: 0.73, Safe Value: 0.5350000262260437
# Step 41: Pstate: [ 0.71  0.07 -1.31], Goal: -1.71, Action: -1.25, Dist: 0.68, Safe Value: 0.5370000004768372
# Step 42: Pstate: [ 0.73  0.02 -1.38], Goal: -1.74, Action: -1.25, Dist: 0.64, Safe Value: 0.5490000247955322
# Step 43: Pstate: [ 0.74 -0.02 -1.44], Goal: -1.77, Action: -1.25, Dist: 0.59, Safe Value: 0.5600000023841858
# Step 44: Pstate: [ 0.74 -0.07 -1.5 ], Goal: -1.8, Action: -1.25, Dist: 0.54, Safe Value: 0.5580000281333923
# Step 45: Pstate: [ 0.75 -0.12 -1.56], Goal: -1.84, Action: -1.25, Dist: 0.5, Safe Value: 0.5479999780654907
# Step 46: Pstate: [ 0.75 -0.17 -1.62], Goal: -1.87, Action: -1.25, Dist: 0.45, Safe Value: 0.5329999923706055
# Step 47: Pstate: [ 0.74 -0.22 -1.69], Goal: -1.9, Action: -1.25, Dist: 0.4, Safe Value: 0.5199999809265137
# Step 48: Pstate: [ 0.74 -0.27 -1.75], Goal: -1.94, Action: -1.25, Dist: 0.35, Safe Value: 0.5090000033378601
# Step 49: Pstate: [ 0.73 -0.32 -1.81], Goal: -1.97, Action: -1.25, Dist: 0.31, Safe Value: 0.49799999594688416
# Step 50: Pstate: [ 0.72 -0.37 -1.88], Goal: -2.01, Action: -1.25, Dist: 0.26, Safe Value: 0.49000000953674316
# Step 51: Pstate: [ 0.7  -0.42 -1.94], Goal: -2.04, Action: -1.25, Dist: 0.21, Safe Value: 0.4749999940395355
# Step 52: Pstate: [ 0.68 -0.47 -2.  ], Goal: -2.08, Action: -1.25, Dist: 0.16, Safe Value: 0.47099998593330383
# Step 53: Pstate: [ 0.66 -0.51 -2.06], Goal: -2.13, Action: -1.25, Dist: 0.11, Safe Value: 0.4620000123977661
# Step 54: Pstate: [ 0.64 -0.56 -2.12], Goal: -2.19, Action: -1.25, Dist: 0.06, Safe Value: 0.4569999873638153
# Step 55: Pstate: [ 0.61 -0.6  -2.19], Goal: -2.3, Action: -1.25, Dist: 0.01, Safe Value: 0.45399999618530273
# Reached the goal!
