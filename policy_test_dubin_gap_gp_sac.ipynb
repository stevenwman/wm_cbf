# %%
from latent_dubins_gap_sac import LatentDubinGap, get_args, state_to_image_pil_hq
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from colorama import Fore, Back, Style
import matplotlib.colors as mcolors

class DubinEnv():
    def __init__(self, start_state, goal_state):
        self.start_state = start_state
        self.curr_state = start_state
        self.goal_state = goal_state
        self.args = get_args()
        self.v = self.args.speed
        self.dt = self.args.dt

    def forward(self, action):
        # Apply the action to the current state
        state_obs, img_obs, state_gt, dones, acs = ([] for _ in range(5))
        pstate = self.curr_state.copy()
        pstate[0] += self.v * np.cos(self.curr_state[2]) * self.dt
        pstate[1] += self.v * np.sin(self.curr_state[2]) * self.dt
        pstate[2] += action * self.dt  # Update the heading angle
        img = state_to_image_pil_hq(pstate, self.args)

        state_obs.append(pstate[2]) # get to observe theta
        state_gt.append(pstate) # gt state
        dones.append(1)
        acs.append(action)
        img_obs.append(img)

        demo = {}
        demo['obs'] = {'image': img_obs, 'state': state_obs, 'priv_state': state_gt}
        demo['actions'] = acs
        demo['dones'] = dones
        return demo, pstate
    
    def goal_ref(self):
        # Calculate the direction towards the goal
        dx = self.goal_state[0] - self.curr_state[0]
        dy = self.goal_state[1] - self.curr_state[1]
        angle_to_goal = np.arctan2(dy, dx)
        ref_theta = angle_to_goal
        delta_theta = ref_theta - self.curr_state[2]
        # Normalize the angle to be within [-pi, pi] using modulo operation
        delta_theta = (delta_theta + np.pi) % (2 * np.pi) - np.pi
        ref_theta_dot = (delta_theta) / self.dt

        return ref_theta, np.clip(ref_theta_dot, -self.args.turnRate, self.args.turnRate)

to_np = lambda x: x.cpu().detach().numpy()
# Out:
# /home/clown2/Desktop/Work/Research/wm_cbf

# %% [markdown]
# ## CBF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.2
gamma = 0.5
simlen = 100
u_min = -dubin_env.args.turnRate
u_max = dubin_env.args.turnRate
u_samples = 1000
u_delta = (u_max - u_min) / u_samples
u_range = np.arange(u_min, u_max + u_delta, u_delta)  # action range for Dubins car
u_range = torch.tensor(u_range, dtype=torch.float32, device=brt.args.device).unsqueeze(-1)  # Convert to tensor

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()
    curr_safe = 1 

    Qzs = brt.evaluate_Q(to_np(feat), u_range)
    # print(f"Qzs: {Qzs}")
    cbf_cond = Qzs > gamma * Vz
    # print(f"CBF Condition: {cbf_cond}")
    Qzs_valid_idx = np.where(cbf_cond)[0]
    # print(f"u_range: {u_range.squeeze(-1).detach().cpu().numpy()}")

    if Qzs_valid_idx.size == 0:
        print(Fore.RED + "No valid actions found, using goal action."+Style.RESET_ALL)
        action = goal_act
    else:
        # Find the action that maximizes the Q-value while satisfying the CBF condition
        Qzs_valid = Qzs[Qzs_valid_idx]
        # Find the action that minimizes the distance to the goal action
        affordable_actions = torch.abs(u_range.squeeze(-1).masked_fill(torch.tensor(~cbf_cond, device=u_range.device), torch.inf) - goal_act)
        # print(f"Affordable actions: {affordable_actions}")
        closest_action = torch.argmin(affordable_actions)
        print(f"Closest action index: {closest_action}, Value: {Qzs[closest_action]}, Goal Action: {goal_act}")
        action = u_range[closest_action][0].detach().cpu().numpy()

    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action

    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    safe_values.append(safe_value)

    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])
    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 2)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot: black edge for trajectory points, red for intervention
# plot: white to red gradient for delta action magnitude
delta_action = np.abs(np.diff(np.array(actions), prepend=actions[0]))
colors = ["white", "red"]
custom_cmap = mcolors.LinearSegmentedColormap.from_list("white_red", colors)
norm = mcolors.Normalize(vmin=0, vmax=u_max - u_min)

# plot the trajectory history and circle obstacle
fig, ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)

for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)

plt.scatter(pss[:,0], pss[:,1], c=delta_action, s=10, label='Trajectory', cmap=custom_cmap, norm=norm, edgecolor='black', linewidth=0.25)
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()

# plot safe value over time
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='CBF Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# /home/clown2/anaconda3/envs/wm_cbf/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# /home/clown2/Desktop/Work/Research/wm_cbf/PytorchReachability/dreamerv3-torch/tools.py:917: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self._scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# Optimizer model_opt has 25916421 trainable variables (excluding margin heads).
# Optimizer margin_nogp has 543233 trainable variables.
# Optimizer margin_gp has 543233 trainable variables.
# Constant alpha: 0.2
# Closest action index: 1000, Value: 0.4462144374847412, Goal Action: 1.25
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.4099999964237213
# Closest action index: 1000, Value: 0.4462144374847412, Goal Action: 1.25
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.4300000071525574
# Closest action index: 1000, Value: 0.4547387659549713, Goal Action: 1.25
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.46000000834465027
# Closest action index: 1000, Value: 0.47152602672576904, Goal Action: 1.25
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.4699999988079071
# Closest action index: 1000, Value: 0.47368061542510986, Goal Action: 1.25
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.47999998927116394
# Closest action index: 1000, Value: 0.469462126493454, Goal Action: 1.25
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.46000000834465027
# Closest action index: 1000, Value: 0.4719127416610718, Goal Action: 1.25
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.46000000834465027
# Closest action index: 1000, Value: 0.5089364647865295, Goal Action: 1.25
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.4699999988079071
# Closest action index: 1000, Value: 0.5407326221466064, Goal Action: 1.25
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.49000000953674316
# Closest action index: 1000, Value: 0.5359678864479065, Goal Action: 1.25
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.5
# Closest action index: 1000, Value: 0.5168868899345398, Goal Action: 1.25
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.49000000953674316
# Closest action index: 1000, Value: 0.4930516183376312, Goal Action: 1.25
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.49000000953674316
# Closest action index: 1000, Value: 0.46892932057380676, Goal Action: 1.25
# Step 13: Pstate: [-1.07  0.66 -0.76], Goal: -0.32, Action: 1.25, Dist: 2.17, Safe Value: 0.49000000953674316
# Closest action index: 1000, Value: 0.44649678468704224, Goal Action: 1.25
# Step 14: Pstate: [-1.03  0.63 -0.7 ], Goal: -0.31, Action: 1.25, Dist: 2.13, Safe Value: 0.49000000953674316
# Closest action index: 1000, Value: 0.4398629665374756, Goal Action: 1.25
# Step 15: Pstate: [-0.99  0.6  -0.63], Goal: -0.3, Action: 1.25, Dist: 2.08, Safe Value: 0.47999998927116394
# Closest action index: 1000, Value: 0.44839438796043396, Goal Action: 1.25
# Step 16: Pstate: [-0.95  0.57 -0.57], Goal: -0.29, Action: 1.25, Dist: 2.03, Safe Value: 0.4699999988079071
# Closest action index: 1000, Value: 0.439431369304657, Goal Action: 1.25
# Step 17: Pstate: [-0.91  0.54 -0.51], Goal: -0.28, Action: 1.25, Dist: 1.99, Safe Value: 0.4399999976158142
# Closest action index: 1000, Value: 0.43861255049705505, Goal Action: 1.25
# Step 18: Pstate: [-0.87  0.51 -0.45], Goal: -0.27, Action: 1.25, Dist: 1.94, Safe Value: 0.4399999976158142
# Closest action index: 1000, Value: 0.44928407669067383, Goal Action: 1.25
# Step 19: Pstate: [-0.82  0.49 -0.38], Goal: -0.27, Action: 1.25, Dist: 1.89, Safe Value: 0.4300000071525574
# Closest action index: 1000, Value: 0.4157571792602539, Goal Action: 1.25
# Step 20: Pstate: [-0.78  0.47 -0.32], Goal: -0.26, Action: 1.25, Dist: 1.84, Safe Value: 0.3400000035762787
# Closest action index: 980, Value: 0.3495508134365082, Goal Action: 1.2007289613043692
# Step 21: Pstate: [-0.73  0.46 -0.26], Goal: -0.26, Action: 1.2000000476837158, Dist: 1.79, Safe Value: 0.1899999976158142
# Closest action index: 514, Value: 0.20700544118881226, Goal Action: 0.03427871558579376
# Step 22: Pstate: [-0.68  0.45 -0.26], Goal: -0.26, Action: 0.03999999910593033, Dist: 1.74, Safe Value: 0.019999999552965164
# Closest action index: 500, Value: 0.01783471554517746, Goal Action: 0.00026464289867078605
# Step 23: Pstate: [-0.63  0.43 -0.26], Goal: -0.26, Action: -0.0, Dist: 1.69, Safe Value: -0.07000000029802322
# Closest action index: 130, Value: -0.0357242152094841, Goal Action: 0.00027247999638824183
# Step 24: Pstate: [-0.58  0.42 -0.31], Goal: -0.26, Action: -0.9200000166893005, Dist: 1.64, Safe Value: -0.20000000298023224
# No valid actions found, using goal action.
# Step 25: Pstate: [-0.54  0.4  -0.26], Goal: -0.26, Action: 0.93, Dist: 1.59, Safe Value: -0.23999999463558197
# No valid actions found, using goal action.
# Step 26: Pstate: [-0.49  0.39 -0.26], Goal: -0.26, Action: 0.03, Dist: 1.54, Safe Value: -0.46000000834465027
# No valid actions found, using goal action.
# Step 27: Pstate: [-0.44  0.38 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.49, Safe Value: -0.5299999713897705
# No valid actions found, using goal action.
# Step 28: Pstate: [-0.39  0.37 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.44, Safe Value: -0.5799999833106995
# No valid actions found, using goal action.
# Step 29: Pstate: [-0.34  0.35 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.39, Safe Value: -0.6100000143051147
# No valid actions found, using goal action.
# Step 30: Pstate: [-0.29  0.34 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.34, Safe Value: -0.6399999856948853
# No valid actions found, using goal action.
# Step 31: Pstate: [-0.25  0.33 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.29, Safe Value: -0.6899999976158142
# No valid actions found, using goal action.
# Step 32: Pstate: [-0.2   0.32 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.24, Safe Value: -0.7300000190734863
# No valid actions found, using goal action.
# Step 33: Pstate: [-0.15  0.3  -0.26], Goal: -0.26, Action: 0.0, Dist: 1.19, Safe Value: -0.75
# No valid actions found, using goal action.
# Step 34: Pstate: [-0.1   0.29 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.14, Safe Value: -0.7599999904632568
# No valid actions found, using goal action.
# Step 35: Pstate: [-0.05  0.28 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.09, Safe Value: -0.7599999904632568
# No valid actions found, using goal action.
# Step 36: Pstate: [-0.    0.26 -0.26], Goal: -0.26, Action: 0.0, Dist: 1.04, Safe Value: -0.75
# No valid actions found, using goal action.
# Step 37: Pstate: [ 0.04  0.25 -0.26], Goal: -0.26, Action: 0.0, Dist: 0.99, Safe Value: -0.7200000286102295
# No valid actions found, using goal action.
# Step 38: Pstate: [ 0.09  0.24 -0.26], Goal: -0.26, Action: 0.0, Dist: 0.94, Safe Value: -0.6499999761581421
# No valid actions found, using goal action.
# Step 39: Pstate: [ 0.14  0.23 -0.26], Goal: -0.26, Action: 0.0, Dist: 0.89, Safe Value: -0.5600000023841858
# No valid actions found, using goal action.
# Step 40: Pstate: [ 0.19  0.21 -0.26], Goal: -0.26, Action: 0.0, Dist: 0.84, Safe Value: -0.4300000071525574
# No valid actions found, using goal action.
# Step 41: Pstate: [ 0.24  0.2  -0.26], Goal: -0.26, Action: 0.0, Dist: 0.79, Safe Value: -0.23999999463558197
# No valid actions found, using goal action.
# Step 42: Pstate: [ 0.29  0.19 -0.26], Goal: -0.26, Action: 0.0, Dist: 0.74, Safe Value: -0.03999999910593033
# Closest action index: 500, Value: 0.12243633717298508, Goal Action: 0.0
# Step 43: Pstate: [ 0.33  0.18 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.69, Safe Value: 0.18000000715255737
# Closest action index: 500, Value: 0.33688509464263916, Goal Action: 2.6645352591003757e-14
# Step 44: Pstate: [ 0.38  0.16 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.64, Safe Value: 0.4099999964237213
# Closest action index: 500, Value: 0.5144619941711426, Goal Action: 5.3290705182007514e-14
# Step 45: Pstate: [ 0.43  0.15 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.59, Safe Value: 0.5600000023841858
# Closest action index: 500, Value: 0.5712571144104004, Goal Action: 8.881784197001252e-14
# Step 46: Pstate: [ 0.48  0.14 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.54, Safe Value: 0.5899999737739563
# Closest action index: 500, Value: 0.5937151312828064, Goal Action: 1.2434497875801753e-13
# Step 47: Pstate: [ 0.53  0.12 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.49, Safe Value: 0.6000000238418579
# Closest action index: 500, Value: 0.6040496826171875, Goal Action: 1.5987211554602254e-13
# Step 48: Pstate: [ 0.58  0.11 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.44, Safe Value: 0.5899999737739563
# Closest action index: 500, Value: 0.5903074145317078, Goal Action: 2.042810365310288e-13
# Step 49: Pstate: [ 0.62  0.1  -0.26], Goal: -0.26, Action: -0.0, Dist: 0.39, Safe Value: 0.5600000023841858
# Closest action index: 500, Value: 0.5551022887229919, Goal Action: 2.575717417130363e-13
# Step 50: Pstate: [ 0.67  0.09 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.34, Safe Value: 0.5199999809265137
# Closest action index: 500, Value: 0.5250543355941772, Goal Action: 3.197442310920451e-13
# Step 51: Pstate: [ 0.72  0.07 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.29, Safe Value: 0.4699999988079071
# Closest action index: 500, Value: 0.4686291217803955, Goal Action: 4.085620730620576e-13
# Step 52: Pstate: [ 0.77  0.06 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.24, Safe Value: 0.41999998688697815
# Closest action index: 500, Value: 0.4223535358905792, Goal Action: 5.151434834260726e-13
# Step 53: Pstate: [ 0.82  0.05 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.19, Safe Value: 0.4099999964237213
# Closest action index: 500, Value: 0.408303439617157, Goal Action: 6.838973831690964e-13
# Step 54: Pstate: [ 0.87  0.04 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.14, Safe Value: 0.4099999964237213
# Closest action index: 500, Value: 0.4100472629070282, Goal Action: 9.50350909079134e-13
# Step 55: Pstate: [ 0.91  0.02 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.09, Safe Value: 0.4099999964237213
# Closest action index: 500, Value: 0.4073415696620941, Goal Action: 1.5187850976872141e-12
# Step 56: Pstate: [ 0.96  0.01 -0.26], Goal: -0.26, Action: -0.0, Dist: 0.04, Safe Value: 0.4099999964237213
# Reached the goal!

# %% [markdown]
# ## LRSF on Latent Dubins

# %%
dubin_env = DubinEnv(start_state=np.array([-1.3, 1.3, -np.pi/2]),
                     goal_state=np.array([1, 0, 0.0]))

brt = LatentDubinGap()

priv_states = []
actions = []
goal_actions = []
current_safe = []
safe_values = []

epsilon = 0.3
simlen = 1000

demo, priv_state = dubin_env.forward(0) # initialize with zero action
feat = brt.data_to_feat(demo)           # render state (took another step in wm)
Vz = brt.evaluate_V(to_np(feat))[0]
Lz = brt.margin_fn(feat)[0][0][0]
safe_value = np.min([Vz, to_np(Lz)])  
demo, priv_state = dubin_env.forward(0) # take real step to match wm step
dubin_env.curr_state = priv_state       # take another step in real
# at this point, Vz should indicate value of current state 

for i in range(simlen):
    # get goal reference direction and action
    goal_dir, goal_act = dubin_env.goal_ref()    
    curr_safe = 1 

    if safe_value < epsilon: 
        safe_action = brt.find_a(feat.detach().cpu().numpy())
        action = safe_action[0]
        curr_safe = 0 # when safe action is engaged
        print(Fore.RED + 'Safe action engaged!' + Style.RESET_ALL)
    else:
        action = goal_act # nominal action otherwise
    
    priv_states.append(priv_state)
    actions.append(action)
    goal_actions.append(goal_act)
    current_safe.append(curr_safe)
    
    feat = brt.data_to_feat(demo, action=action) # take action in wm
    demo, priv_state = dubin_env.forward(action) # take action in real
    Vz = brt.evaluate_V(to_np(feat))[0] # Vz after action
    Lz = brt.margin_fn(feat)[0][0][0]
    safe_value = np.min([Vz, to_np(Lz)])   
    dubin_env.curr_state = priv_state  # update state after taking action
    
    safe_values.append(safe_value)
    distance = np.linalg.norm(dubin_env.goal_state[:2] - dubin_env.curr_state[:2])

    print(f"Step {i+1}: Pstate: {np.round(priv_state,2)}, "
          f"Goal: {np.round(goal_dir,2)}, "
          f"Action: {np.around(action,2)}, "
          f"Dist: {np.round(distance,2)}, "
          f"Safe Value: {np.round(safe_value, 3)}")
    
    if distance < 0.05:
        print("Reached the goal!")
        break

# plot: black edge for trajectory points, red for intervention
# plot: white to red gradient for delta action magnitude
delta_action = np.abs(np.diff(np.array(actions), prepend=actions[0]))
colors = ["white", "red"]
custom_cmap = mcolors.LinearSegmentedColormap.from_list("white_red", colors)
norm = mcolors.Normalize(vmin=0, vmax=u_max - u_min)

# plot the trajectory history and circle obstacle 
fig,ax = plt.subplots()
# hardcoded with existing limits
sf = 1 # scale factor
plt.xlim([sf*brt.args.x_min, sf*brt.args.x_max])
plt.ylim([sf*brt.args.y_min, sf*brt.args.y_max])
plt.axis('off')
fig.set_size_inches(5, 5)
pss = np.array(priv_states)
for x_obs, y_obs, r_obs in zip(brt.args.obs_x, brt.args.obs_y, brt.args.obs_r):
    circle = patches.Circle((x_obs, y_obs), r_obs, edgecolor=(1,0,0), facecolor='none')
    ax.add_patch(circle)
safe_action_idx = np.where(np.array(current_safe) == 1)
unsafe_action_idx = np.where(np.array(current_safe) == 0)
plt.scatter(pss[safe_action_idx][:,0], pss[safe_action_idx][:,1], c=delta_action[safe_action_idx], s=10, label='Trajectory', cmap=custom_cmap, norm=norm, linewidths=0.25, edgecolor='black')
plt.scatter(pss[unsafe_action_idx][:,0], pss[unsafe_action_idx][:,1], c=delta_action[unsafe_action_idx], s=10, label='Trajectory', cmap=custom_cmap, norm=norm, linewidths=0.25, edgecolor='red')
plt.scatter(dubin_env.goal_state[0], dubin_env.goal_state[1], c='green', s=50, label='Goal')

# plot action over time
plt.figure()
plt.plot(np.array(actions), label='Action', marker='o')
plt.plot(np.array(goal_actions), label='Goal Action', marker='o', linestyle='--', color='green')
plt.axhline(y=dubin_env.args.turnRate, color='r', linestyle='--', label='Max Turn Rate')
plt.axhline(y=-dubin_env.args.turnRate, color='r', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Action Value')
plt.title('Action Over Time')
plt.legend()
plt.show()
    
plt.figure()
plt.plot(safe_values, label='Safe Value', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='Safety Margin')
plt.xlabel('Time Step')
plt.ylabel('Safe Value')
plt.title('Safe Value Over Time')
plt.legend()
plt.show()
# Out:
# Encoder CNN shapes: {'image': (128, 128, 3)}
# Encoder MLP shapes: {'obs_state': (2,)}
# Decoder CNN shapes: {'image': (128, 128, 3)}
# Decoder MLP shapes: {'obs_state': (2,)}
# Optimizer model_opt has 27002886 variables.
# Step 1: Pstate: [-1.3   1.2  -1.51], Goal: -0.5, Action: 1.25, Dist: 2.59, Safe Value: 0.7129999995231628
# Step 2: Pstate: [-1.3   1.15 -1.45], Goal: -0.48, Action: 1.25, Dist: 2.57, Safe Value: 0.7279999852180481
# Step 3: Pstate: [-1.29  1.1  -1.38], Goal: -0.46, Action: 1.25, Dist: 2.54, Safe Value: 0.7400000095367432
# Step 4: Pstate: [-1.28  1.05 -1.32], Goal: -0.45, Action: 1.25, Dist: 2.51, Safe Value: 0.7519999742507935
# Step 5: Pstate: [-1.27  1.   -1.26], Goal: -0.43, Action: 1.25, Dist: 2.48, Safe Value: 0.7580000162124634
# Step 6: Pstate: [-1.25  0.96 -1.2 ], Goal: -0.42, Action: 1.25, Dist: 2.45, Safe Value: 0.7639999985694885
# Step 7: Pstate: [-1.24  0.91 -1.13], Goal: -0.4, Action: 1.25, Dist: 2.41, Safe Value: 0.7680000066757202
# Step 8: Pstate: [-1.21  0.86 -1.07], Goal: -0.39, Action: 1.25, Dist: 2.38, Safe Value: 0.7689999938011169
# Step 9: Pstate: [-1.19  0.82 -1.01], Goal: -0.37, Action: 1.25, Dist: 2.34, Safe Value: 0.7649999856948853
# Step 10: Pstate: [-1.16  0.78 -0.95], Goal: -0.36, Action: 1.25, Dist: 2.3, Safe Value: 0.75
# Step 11: Pstate: [-1.13  0.74 -0.88], Goal: -0.34, Action: 1.25, Dist: 2.26, Safe Value: 0.7300000190734863
# Step 12: Pstate: [-1.1   0.7  -0.82], Goal: -0.33, Action: 1.25, Dist: 2.22, Safe Value: 0.6990000009536743
# Step 13: Pstate: [-1.07  0.66 -0.76], Goal: -0.32, Action: 1.25, Dist: 2.17, Safe Value: 0.6610000133514404
# Step 14: Pstate: [-1.03  0.63 -0.7 ], Goal: -0.31, Action: 1.25, Dist: 2.13, Safe Value: 0.6159999966621399
# Step 15: Pstate: [-0.99  0.6  -0.63], Goal: -0.3, Action: 1.25, Dist: 2.08, Safe Value: 0.5789999961853027
# Step 16: Pstate: [-0.95  0.57 -0.57], Goal: -0.29, Action: 1.25, Dist: 2.03, Safe Value: 0.550000011920929
# Step 17: Pstate: [-0.91  0.54 -0.51], Goal: -0.28, Action: 1.25, Dist: 1.99, Safe Value: 0.5180000066757202
# Step 18: Pstate: [-0.87  0.51 -0.45], Goal: -0.27, Action: 1.25, Dist: 1.94, Safe Value: 0.49300000071525574
# Step 19: Pstate: [-0.82  0.49 -0.38], Goal: -0.27, Action: 1.25, Dist: 1.89, Safe Value: 0.45500001311302185
# Step 20: Pstate: [-0.78  0.47 -0.32], Goal: -0.26, Action: 1.25, Dist: 1.84, Safe Value: 0.38499999046325684
# Step 21: Pstate: [-0.73  0.46 -0.26], Goal: -0.26, Action: 1.2, Dist: 1.79, Safe Value: 0.2840000092983246
# Safe action engaged!
# Step 22: Pstate: [-0.68  0.45 -0.32], Goal: -0.26, Action: -1.25, Dist: 1.74, Safe Value: 0.09200000017881393
# Safe action engaged!
# Step 23: Pstate: [-0.63  0.43 -0.39], Goal: -0.26, Action: -1.25, Dist: 1.69, Safe Value: 0.12200000137090683
# Safe action engaged!
# Step 24: Pstate: [-0.59  0.41 -0.45], Goal: -0.26, Action: -1.25, Dist: 1.64, Safe Value: 0.10499999672174454
# Safe action engaged!
# Step 25: Pstate: [-0.54  0.39 -0.51], Goal: -0.25, Action: -1.25, Dist: 1.59, Safe Value: 0.10999999940395355
# Safe action engaged!
# Step 26: Pstate: [-0.5   0.36 -0.57], Goal: -0.25, Action: -1.25, Dist: 1.54, Safe Value: 0.1379999965429306
# Safe action engaged!
# Step 27: Pstate: [-0.46  0.34 -0.64], Goal: -0.24, Action: -1.25, Dist: 1.49, Safe Value: 0.1420000046491623
# Safe action engaged!
# Step 28: Pstate: [-0.42  0.31 -0.7 ], Goal: -0.23, Action: -1.25, Dist: 1.45, Safe Value: 0.14499999582767487
# Safe action engaged!
# Step 29: Pstate: [-0.38  0.28 -0.76], Goal: -0.21, Action: -1.25, Dist: 1.4, Safe Value: 0.1589999943971634
# Safe action engaged!
# Step 30: Pstate: [-0.34  0.24 -0.82], Goal: -0.2, Action: -1.25, Dist: 1.36, Safe Value: 0.1469999998807907
# Safe action engaged!
# Step 31: Pstate: [-0.31  0.2  -0.88], Goal: -0.18, Action: -1.0499999523162842, Dist: 1.32, Safe Value: 0.01600000075995922
# Safe action engaged!
# Step 32: Pstate: [-0.28  0.17 -0.81], Goal: -0.16, Action: 1.2400000095367432, Dist: 1.29, Safe Value: 0.017999999225139618
# Safe action engaged!
# Step 33: Pstate: [-0.24  0.13 -0.75], Goal: -0.13, Action: 1.25, Dist: 1.25, Safe Value: 0.09099999815225601
# Safe action engaged!
# Step 34: Pstate: [-0.2   0.1  -0.69], Goal: -0.1, Action: 1.25, Dist: 1.21, Safe Value: 0.16200000047683716
# Safe action engaged!
# Step 35: Pstate: [-0.17  0.06 -0.63], Goal: -0.08, Action: 1.25, Dist: 1.17, Safe Value: 0.1860000044107437
# Safe action engaged!
# Step 36: Pstate: [-0.13  0.03 -0.56], Goal: -0.05, Action: 1.25, Dist: 1.13, Safe Value: 0.20100000500679016
# Safe action engaged!
# Step 37: Pstate: [-0.08  0.01 -0.5 ], Goal: -0.03, Action: 1.25, Dist: 1.08, Safe Value: 0.2160000056028366
# Safe action engaged!
# Step 38: Pstate: [-0.04 -0.02 -0.44], Goal: -0.01, Action: 1.25, Dist: 1.04, Safe Value: 0.2150000035762787
# Safe action engaged!
# Step 39: Pstate: [ 0.01 -0.04 -0.38], Goal: 0.02, Action: 1.25, Dist: 0.99, Safe Value: 0.20800000429153442
# Safe action engaged!
# Step 40: Pstate: [ 0.05 -0.06 -0.31], Goal: 0.04, Action: 1.25, Dist: 0.95, Safe Value: 0.20999999344348907
# Safe action engaged!
# Step 41: Pstate: [ 0.1  -0.07 -0.25], Goal: 0.06, Action: 1.25, Dist: 0.9, Safe Value: 0.2160000056028366
# Safe action engaged!
# Step 42: Pstate: [ 0.15 -0.08 -0.19], Goal: 0.08, Action: 1.25, Dist: 0.86, Safe Value: 0.24799999594688416
# Safe action engaged!
# Step 43: Pstate: [ 0.2  -0.09 -0.13], Goal: 0.1, Action: 1.25, Dist: 0.81, Safe Value: 0.29899999499320984
# Safe action engaged!
# Step 44: Pstate: [ 0.25 -0.1  -0.06], Goal: 0.12, Action: 1.25, Dist: 0.76, Safe Value: 0.37599998712539673
# Step 45: Pstate: [ 0.3 -0.1 -0. ], Goal: 0.13, Action: 1.25, Dist: 0.71, Safe Value: 0.4480000138282776
# Step 46: Pstate: [ 0.35 -0.1   0.06], Goal: 0.15, Action: 1.25, Dist: 0.66, Safe Value: 0.49300000071525574
# Step 47: Pstate: [ 0.4  -0.1   0.12], Goal: 0.16, Action: 1.25, Dist: 0.61, Safe Value: 0.5889999866485596
# Step 48: Pstate: [ 0.45 -0.09  0.16], Goal: 0.16, Action: 0.81, Dist: 0.56, Safe Value: 0.6430000066757202
# Step 49: Pstate: [ 0.5  -0.09  0.17], Goal: 0.17, Action: 0.07, Dist: 0.51, Safe Value: 0.6700000166893005
# Step 50: Pstate: [ 0.55 -0.08  0.17], Goal: 0.17, Action: 0.01, Dist: 0.46, Safe Value: 0.6579999923706055
# Step 51: Pstate: [ 0.59 -0.07  0.17], Goal: 0.17, Action: 0.0, Dist: 0.41, Safe Value: 0.6380000114440918
# Step 52: Pstate: [ 0.64 -0.06  0.17], Goal: 0.17, Action: 0.0, Dist: 0.36, Safe Value: 0.6190000176429749
# Step 53: Pstate: [ 0.69 -0.05  0.17], Goal: 0.17, Action: 0.0, Dist: 0.31, Safe Value: 0.5910000205039978
# Step 54: Pstate: [ 0.74 -0.04  0.17], Goal: 0.17, Action: 0.0, Dist: 0.26, Safe Value: 0.5519999861717224
# Step 55: Pstate: [ 0.79 -0.04  0.17], Goal: 0.17, Action: 0.0, Dist: 0.21, Safe Value: 0.5249999761581421
# Step 56: Pstate: [ 0.84 -0.03  0.17], Goal: 0.17, Action: 0.0, Dist: 0.16, Safe Value: 0.4909999966621399
# Step 57: Pstate: [ 0.89 -0.02  0.17], Goal: 0.17, Action: 0.0, Dist: 0.11, Safe Value: 0.44200000166893005
# Step 58: Pstate: [ 0.94 -0.01  0.17], Goal: 0.17, Action: 0.0, Dist: 0.06, Safe Value: 0.3790000081062317
# Step 59: Pstate: [ 0.99 -0.    0.17], Goal: 0.17, Action: 0.0, Dist: 0.01, Safe Value: 0.3109999895095825
# Reached the goal!
